# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
from numpy.random import randn

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime as dt

# %%
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 85)

# %%
nib = pd.read_csv('nib.csv')

# %%
nib['Date'] = nib['Date'].apply(pd.to_datetime)

# %%
nib.dtypes
# Out:
# Tid                            float64
# Payer BVN                      float64
# BVN/PER TRANSACTIONS           float64
# Date                    datetime64[ns]
# Issuing Bank                    object
# Issuing Banks Name              object
# Receiving Bank                  object
# Receiving Bank Name             object
# Amount                         float64
# trans_location                  object
# Terminal Id                    float64
# MERCHANT                        object
# NIBBS RATE                     float64
# NIBBS COMMISION                 object
# Unnamed: 14                    float64
# dtype: object

# %%
nib.isna().sum()
# Out:
# Tid                     1526
# Payer BVN               1525
# BVN/PER TRANSACTIONS    1525
# Date                    1525
# Issuing Bank            1525
# Issuing Banks Name      1526
# Receiving Bank          1525
# Receiving Bank Name     1526
# Amount                  1525
# trans_location          1525
# Terminal Id             1525
# MERCHANT                1525
# NIBBS RATE              1525
# NIBBS COMMISION         1525
# Unnamed: 14             1999
# dtype: int64

# %%
nib.dropna(how='all', axis = 'index', inplace=True)

# %%
nib.tail(3)
# Out:
#              Tid     Payer BVN  BVN/PER TRANSACTIONS                Date  \
# 472   11128715.0  2.222222e+10                   5.0          2019-03-31
# 473   11128708.0  2.222222e+10                   5.0          2019-03-31
# 1999         NaN  0.000000e+00                   0.0 1899-12-30 00:00:00
#
#      Issuing Bank Issuing Banks Name Receiving Bank Receiving Bank Name  \
# 472        Bank D            EcoBank         Bank G          Unity Bank
# 473        Bank E         Union Bank         Bank j                FCMB
# 1999            0                NaN              0                 NaN
#
#        Amount trans_location  Terminal Id MERCHANT  NIBBS RATE  \
# 472    8000.0          LEKKI      77088.0    Sobee        0.01
# 473   52100.0          LEKKI      77022.0     Spar        0.01
# 1999      0.0              0          0.0        0        0.00
#
#      NIBBS COMMISION  Unnamed: 14
# 472              80           NaN
# 473             521           NaN
# ...

# %%
 nib.drop([1999], axis=0, inplace=True)

# %%
nib.drop(columns=['Unnamed: 14'], inplace=True)

# %%
nib.tail(3)
# Out:
#             Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 471  11128722.0  2.222222e+10                   5.0 2019-03-30       Bank C
# 472  11128715.0  2.222222e+10                   5.0 2019-03-31       Bank D
# 473  11128708.0  2.222222e+10                   5.0 2019-03-31       Bank E
#
#     Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 471      Fidelity Bank         Bank I                 UBA  39000.0
# 472            EcoBank         Bank G          Unity Bank   8000.0
# 473         Union Bank         Bank j                FCMB  52100.0
#
#     trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# 471          LEKKI      77022.0     Spar        0.01            390
# 472          LEKKI      77088.0    Sobee        0.01             80
# 473          LEKKI      77022.0     Spar        0.01            521

# %%
nib['MERCHANT'].unique()
# Out:
# array(['Sobee', 'Spar', 'Daytona', 'Ebano', 'FastMart', 'Game',
#        'Grand Square', 'NY Supermarket', 'Renee', 'Shporite'],
#       dtype=object)

# %%
nib['trans_location'].unique()
# Out:
# array(['IKEJA', 'MUSHIN', 'LEKKI', 'IKOYI', 'VICTORIA ISLAND', 'YABA',
#        'MARYLAND', 'IKORODU'], dtype=object)

# %%
nib['Issuing Banks Name'].unique()
# Out:
# array(['First Bank', 'Zenith Bank', 'GTBank', 'Fidelity Bank', 'EcoBank',
#        'Union Bank', 'Unity Bank', 'Access Bank', 'UBA', 'FCMB'],
#       dtype=object)

# %% [markdown]
# # QUESTIONS FOR NIBSS QUERY

# %% [markdown]
# # 1. Merchant with the highest volume of transaction per location?

# %%
#we have eleven merchant in all the location
#we have eight locations
#now let group each merchant by location

# %% [markdown]
# # merchant location for ikeja

# %%
merchant_location = nib.groupby(['trans_location'])
merchant_location= merchant_location.get_group('IKEJA')
merchant_location.head(2)
# Out:
#           Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 0  11132019.0  2.222222e+10                   5.0 2019-01-01       bank F
# 8  11131963.0  2.222222e+10                   4.0 2019-01-01       Bank C
#
#   Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 0         First Bank         Bank A         Zenith Bank  90000.0
# 8      Fidelity Bank         Bank B              GTBank  65000.0
#
#   trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# 0          IKEJA      77088.0    Sobee        0.01            900
# 8          IKEJA      77000.0    Renee        0.01            650

# %%
#top five merchant with the highest volume at ikeja location

Merchant_with_the_highest_volume_in_ikeja =(merchant_location['Amount']> 3000000)

# %%
merchant_location.loc[Merchant_with_the_highest_volume_in_ikeja,['Amount', 'trans_location', 'MERCHANT',]]
# Out:
#          Amount trans_location        MERCHANT
# 128   4000000.0          IKEJA        FastMart
# 147  12000000.0          IKEJA           Renee
# 165   4000000.0          IKEJA  NY Supermarket
# 168   3400000.0          IKEJA         Daytona
# 174   3900500.0          IKEJA           Renee

# %% [markdown]
# # merchant location for MUSHIN

# %%
merchant_location_two = nib.groupby(['trans_location'])
merchant_location_two= merchant_location_two.get_group('MUSHIN')
merchant_location_two.head(2)
# Out:
#           Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 1  11132012.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 9  11131956.0  2.222222e+10                   4.0 2019-01-01       Bank D
#
#   Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 1        Zenith Bank         Bank B              GTBank  12750.0
# 9            EcoBank         Bank B              GTBank  95000.0
#
#   trans_location  Terminal Id  MERCHANT  NIBBS RATE NIBBS COMMISION
# 1         MUSHIN      77022.0      Spar        0.01            128
# 9         MUSHIN      77011.0  Shporite        0.01            950

# %%
#top six merchant with the highest volume at mushin location

Merchant_with_the_highest_volume_in_mushin =(merchant_location_two['Amount']> 300000)

# %%
merchant_location_two.loc[Merchant_with_the_highest_volume_in_mushin,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#         Amount trans_location      MERCHANT
# 158   632000.0         MUSHIN      Shporite
# 166   311000.0         MUSHIN         Renee
# 172  2400000.0         MUSHIN  Grand Square
# 332   345000.0         MUSHIN         Sobee
# 334   872110.0         MUSHIN       Daytona
# 395   670000.0         MUSHIN      FastMart

# %% [markdown]
# # merchant location for LEKKI

# %%
merchant_location_three = nib.groupby(['trans_location'])
merchant_location_three= merchant_location_three.get_group('LEKKI')
merchant_location_three.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 2   11132005.0  2.222222e+10                   5.0 2019-01-01       bank F
# 10  11131949.0  2.222222e+10                   4.0 2019-01-02       Bank E
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 2          First Bank         Bank B              GTBank  13800.0
# 10         Union Bank         Bank B              GTBank  54000.0
#
#    trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# 2           LEKKI      77066.0  Daytona        0.01            138
# 10          LEKKI      77088.0    Sobee        0.01            540

# %%
#top six merchant with the highest volume at lekki location

Merchant_with_the_highest_volume_in_lekki =(merchant_location_three['Amount']> 300000)

# %%
merchant_location_three.loc[Merchant_with_the_highest_volume_in_lekki,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#         Amount trans_location        MERCHANT
# 18    780000.0          LEKKI           Renee
# 47    500000.0          LEKKI    Grand Square
# 48   1500000.0          LEKKI  NY Supermarket
# 126   890000.0          LEKKI         Daytona
# 173   480000.0          LEKKI  NY Supermarket
# 443   670000.0          LEKKI           Sobee

# %% [markdown]
# # merchant location for ikoyi

# %%
merchant_location_four = nib.groupby(['trans_location'])
merchant_location_four= merchant_location_four.get_group('IKOYI')
merchant_location_four.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 3   11131998.0  2.222222e+10                   4.0 2019-01-01       bank A
# 11  11131942.0  2.222222e+10                   4.0 2019-01-02       Bank F
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 3         Zenith Bank         Bank B              GTBank  670000.0
# 11         First Bank         Bank B              GTBank    7000.0
#
#    trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# 3           IKOYI      77033.0    Ebano        0.01          6,700
# 11          IKOYI      77022.0     Spar        0.01             70

# %%
#top ten merchant with the highest volume at ikoyi location

Merchant_with_the_highest_volume_in_ikoyi =(merchant_location_four['Amount']> 300000)

# %%
merchant_location_four.loc[Merchant_with_the_highest_volume_in_ikoyi,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#         Amount trans_location        MERCHANT
# 3     670000.0          IKOYI           Ebano
# 127  2500000.0          IKOYI           Ebano
# 177  2100000.0          IKOYI           Ebano
# 181  3000000.0          IKOYI  NY Supermarket
# 187  8000000.0          IKOYI        FastMart
# 227   709680.0          IKOYI        Shporite
# 242   340000.0          IKOYI    Grand Square
# 267   340000.0          IKOYI        Shporite
# 290   340000.0          IKOYI           Renee
# 397   350000.0          IKOYI    Grand Square

# %% [markdown]
# # merchant location for VICTORIA ISLAND

# %%
merchant_location_five = nib.groupby(['trans_location'])
merchant_location_five= merchant_location_five.get_group('VICTORIA ISLAND')
merchant_location_five.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 4   11131991.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 12  11131935.0  2.222222e+10                   4.0 2019-01-02       Bank G
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 4         Zenith Bank         Bank B              GTBank  220000.0
# 12         Unity Bank         Bank B              GTBank   12750.0
#
#      trans_location  Terminal Id        MERCHANT  NIBBS RATE NIBBS COMMISION
# 4   VICTORIA ISLAND      77099.0        FastMart        0.01          2,200
# 12  VICTORIA ISLAND      77077.0  NY Supermarket        0.01            128

# %%
#top six merchant with the highest volume at VICTORIA ISLAND location

Merchant_with_the_highest_volume_in_vi =(merchant_location_five['Amount']> 500000)

# %%
merchant_location_five.loc[Merchant_with_the_highest_volume_in_vi,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#        Amount   trans_location        MERCHANT
# 14   709680.0  VICTORIA ISLAND        Shporite
# 58   890000.0  VICTORIA ISLAND            Spar
# 82   709680.0  VICTORIA ISLAND  NY Supermarket
# 86   780000.0  VICTORIA ISLAND  NY Supermarket
# 87   789000.0  VICTORIA ISLAND           Renee
# 406  709680.0  VICTORIA ISLAND            Game

# %% [markdown]
# # merchant location for YABA

# %%
merchant_location_six = nib.groupby(['trans_location'])
merchant_location_six= merchant_location_six.get_group('YABA')
merchant_location_six.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 5   11131984.0  2.222222e+10                   4.0 2019-01-01       bank A
# 26  11131837.0  2.222222e+10                   4.0 2019-01-03       bank I
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 5         Zenith Bank         Bank B              GTBank  350000.0
# 26                UBA         Bank B              GTBank  140000.0
#
#    trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# 5            YABA      77055.0     Game        0.01          3,500
# 26           YABA      77022.0     Spar        0.01          1,400

# %%
#top six merchant with the highest volume at VICTORIA ISLAND location

Merchant_with_the_highest_volume_in_yaba =(merchant_location_six['Amount']> 500000)

# %%
merchant_location_six.loc[Merchant_with_the_highest_volume_in_yaba,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#         Amount trans_location      MERCHANT
# 59   2500000.0           YABA  Grand Square
# 71    670000.0           YABA      FastMart
# 152  1600000.0           YABA         Ebano
# 160   900000.0           YABA       Daytona
# 183  1200000.0           YABA      Shporite
# 232   789000.0           YABA         Renee

# %% [markdown]
# # merchant location for MARYLAND

# %%
merchant_location_seven = nib.groupby(['trans_location'])
merchant_location_seven= merchant_location_seven.get_group('MARYLAND')
merchant_location_seven.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 6   11131977.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 19  11131886.0  2.222222e+10                   4.0 2019-01-03       bank A
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 6         Zenith Bank         Bank B              GTBank   23000.0
# 19        Zenith Bank         Bank B              GTBank  789000.0
#
#    trans_location  Terminal Id      MERCHANT  NIBBS RATE NIBBS COMMISION
# 6        MARYLAND      77044.0  Grand Square        0.01            230
# 19       MARYLAND      77011.0      Shporite        0.01          7,890

# %%
#top six merchant with the highest volume at VICTORIA ISLAND location

Merchant_with_the_highest_volume_in_maryland =(merchant_location_seven['Amount']> 500000)

# %%
merchant_location_seven.loc[Merchant_with_the_highest_volume_in_maryland,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#         Amount trans_location        MERCHANT
# 19    789000.0       MARYLAND        Shporite
# 60   4000000.0       MARYLAND  NY Supermarket
# 153   931000.0       MARYLAND        FastMart
# 161   670000.0       MARYLAND           Ebano
# 162  2500000.0       MARYLAND        FastMart
# 200  1230080.0       MARYLAND  NY Supermarket

# %% [markdown]
# # merchant location for IKORODU

# %%
merchant_location_eight = nib.groupby(['trans_location'])
merchant_location_eight= merchant_location_eight.get_group('IKORODU')
merchant_location_eight.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 7   11131970.0  2.222222e+10                   4.0 2019-01-01       Bank B
# 20  11131879.0  2.222222e+10                   4.0 2019-01-03       Bank A
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name  Amount  \
# 7              GTBank         Bank B              GTBank  1200.0
# 20        Zenith Bank         Bank A         Zenith Bank  5000.0
#
#    trans_location  Terminal Id        MERCHANT  NIBBS RATE NIBBS COMMISION
# 7         IKORODU      77077.0  NY Supermarket        0.01             12
# 20        IKORODU      77088.0           Sobee        0.01             50

# %%
#top two merchant with the highest volume at VICTORIA ISLAND location

Merchant_with_the_highest_volume_in_ikorodu =(merchant_location_eight['Amount']> 500000)

# %%
merchant_location_eight.loc[Merchant_with_the_highest_volume_in_ikorodu,['Amount', 'trans_location', 'MERCHANT', ]]
# Out:
#        Amount trans_location        MERCHANT
# 154  788000.0        IKORODU            Game
# 231  780000.0        IKORODU  NY Supermarket

# %% [markdown]
# # NIBSS QUESTION 1b

# %% [markdown]
# # What Merchant location has the highest number of transactions?

# %%
merchant_location_with_highest_num_transactions =(nib['Amount']> 7000000)

# %%
nib.loc[merchant_location_with_highest_num_transactions, ['Amount', 'trans_location', 'MERCHANT',]]
# Out:
#          Amount trans_location  MERCHANT
# 147  12000000.0          IKEJA     Renee
# 187   8000000.0          IKOYI  FastMart

# %% [markdown]
# # NIBSS QUESTION 1c

# %% [markdown]
# # show monthly transactions and the Merchant that had the highest volume of transactions?

# %%
#january transaction and the merchant with the highest volume of transaction


jen_tran_and_merchant_highest = nib.groupby(['Date'])
jen_tran_and_merchant_highest= jen_tran_and_merchant_highest.get_group('2019-01')
jen_tran_and_merchant_highest.head()
# Out:
#           Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 0  11132019.0  2.222222e+10                   5.0 2019-01-01       bank F
# 1  11132012.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 2  11132005.0  2.222222e+10                   5.0 2019-01-01       bank F
# 3  11131998.0  2.222222e+10                   4.0 2019-01-01       bank A
# 4  11131991.0  2.222222e+10                   4.0 2019-01-01       Bank A
#
#   Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 0         First Bank         Bank A         Zenith Bank   90000.0
# 1        Zenith Bank         Bank B              GTBank   12750.0
# 2         First Bank         Bank B              GTBank   13800.0
# 3        Zenith Bank         Bank B              GTBank  670000.0
# 4        Zenith Bank         Bank B              GTBank  220000.0
#
#     trans_location  Terminal Id  MERCHANT  NIBBS RATE NIBBS COMMISION
# ...

# %%
merchant_loc =(jen_tran_and_merchant_highest['Amount']> 70000)

# %%
jen_tran_and_merchant_highest.loc[merchant_loc,['Amount', 'trans_location', 'MERCHANT', 'Receiving Bank Name' ]]
# Out:
#      Amount   trans_location  MERCHANT Receiving Bank Name
# 0   90000.0            IKEJA     Sobee         Zenith Bank
# 3  670000.0            IKOYI     Ebano              GTBank
# 4  220000.0  VICTORIA ISLAND  FastMart              GTBank
# 5  350000.0             YABA      Game              GTBank
# 9   95000.0           MUSHIN  Shporite              GTBank

# %% [markdown]
# # NIBSS QUESTION 1d

# %% [markdown]
# # what merchant received the top volume of transactions in the first 3 months of 2019?

# %%
#merchant top volume of transaction in the first three month of 2019

merchant_reciev_top_three_vl_of_tra_in_d_fr_tri_m = (nib['Date']>='2019-01-01') & (nib['Date']<'2019-03-30')
nib.loc[merchant_reciev_top_three_vl_of_tra_in_d_fr_tri_m]
# Out:
#             Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 0    11132019.0  2.222222e+10                   5.0 2019-01-01       bank F
# 1    11132012.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 2    11132005.0  2.222222e+10                   5.0 2019-01-01       bank F
# 3    11131998.0  2.222222e+10                   4.0 2019-01-01       bank A
# 4    11131991.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 5    11131984.0  2.222222e+10                   4.0 2019-01-01       bank A
# 6    11131977.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 7    11131970.0  2.222222e+10                   4.0 2019-01-01       Bank B
# 8    11131963.0  2.222222e+10                   4.0 2019-01-01       Bank C
# 9    11131956.0  2.222222e+10                   4.0 2019-01-01       Bank D
# 10   11131949.0  2.222222e+10                   4.0 2019-01-02       Bank E
# ...

# %%
m_v_h=nib.loc[merchant_reciev_top_three_vl_of_tra_in_d_fr_tri_m]
merchant_reciev_top_three_vl_of_tra_in_d_fr_tri_m =(m_v_h['Amount']> 4000000)

# %%
m_v_h.loc[merchant_reciev_top_three_vl_of_tra_in_d_fr_tri_m,['Amount', 'trans_location', 'MERCHANT', 'Receiving Bank Name' ]]
# Out:
#          Amount trans_location  MERCHANT Receiving Bank Name
# 147  12000000.0          IKEJA     Renee         Access Bank
# 187   8000000.0          IKOYI  FastMart          Unity Bank

# %% [markdown]
# # on the 15th of january, what bank made the highest transection. and from what merchant and customer.

# %%
fifteen_jen_tran_bank_highest = nib.groupby(['Date'])
fifteen_jen_tran_bank_highest= fifteen_jen_tran_bank_highest.get_group('2019-01-15')
fifteen_jen_tran_bank_highest.head()
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 77  11131480.0  2.222222e+10                   4.0 2019-01-15       Bank C
# 78  11131473.0  2.222222e+10                   4.0 2019-01-15       Bank E
# 79  11131466.0  2.222222e+10                   4.0 2019-01-15       Bank E
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 77      Fidelity Bank         Bank I                 UBA  95000.0
# 78         Union Bank         Bank G          Unity Bank  54000.0
# 79         Union Bank         Bank H         Access Bank   7000.0
#
#    trans_location  Terminal Id        MERCHANT  NIBBS RATE NIBBS COMMISION
# 77          IKEJA      77088.0           Sobee        0.01            950
# 78         MUSHIN      77077.0  NY Supermarket        0.01            540
# 79          LEKKI      77000.0           Renee        0.01             70

# %%
bank_highest =(fifteen_jen_tran_bank_highest['Amount']> 70000)

# %%
fifteen_jen_tran_bank_highest.loc[bank_highest,['Amount', 'Date', 'MERCHANT', 'Receiving Bank Name', 'Payer BVN']]
# Out:
#      Amount       Date MERCHANT Receiving Bank Name     Payer BVN
# 77  95000.0 2019-01-15    Sobee                 UBA  2.222222e+10

# %% [markdown]
# # what customer made the highest transaction on the 27th of january.

# %%
tweentyseven_jen_tran_customer_highest = nib.groupby(['Date'])
tweentyseven_jen_tran_customer_highest= tweentyseven_jen_tran_customer_highest.get_group('2019-01-27')
tweentyseven_jen_tran_customer_highest.head()
# Out:
#             Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 121  11131172.0  2.222222e+10                   4.0 2019-01-27       Bank A
# 122  11131165.0  2.222222e+10                   4.0 2019-01-27       Bank B
# 123  11131158.0  2.222222e+10                   4.0 2019-01-27       Bank C
# 124  11131151.0  2.222222e+10                   4.0 2019-01-27       Bank D
# 125  11131144.0  2.222222e+10                   4.0 2019-01-27       Bank E
#
#     Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 121        Zenith Bank         Bank I                 UBA  15000.0
# 122             GTBank         Bank G          Unity Bank  30000.0
# 123      Fidelity Bank         Bank G          Unity Bank  45000.0
# 124            EcoBank         Bank j                FCMB  45000.0
# 125         Union Bank         Bank G          Unity Bank  20750.0
#
#     trans_location  Terminal Id        MERCHANT  NIBBS RATE NIBBS COMMISION
# ...

# %%
customer_highest =(tweentyseven_jen_tran_customer_highest['Amount']> 70000)

# %%
tweentyseven_jen_tran_customer_highest.loc[customer_highest,['Amount', 'Date', 'Payer BVN']]
# Out:
#         Amount       Date     Payer BVN
# 126   890000.0 2019-01-27  2.222222e+10
# 127  2500000.0 2019-01-27  2.222222e+10

# %% [markdown]
# # NIBSS QUESTION 2

# %% [markdown]
# # Customer with the highest volume of transaction per merchant?

# %%
customer_highest_v_per_customer = nib.groupby(['MERCHANT'])
customer_highest_v_per_customer= customer_highest_v_per_customer.get_group('Sobee')
customer_highest_v_per_customer.head(2)
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 0   11132019.0  2.222222e+10                   5.0 2019-01-01       bank F
# 10  11131949.0  2.222222e+10                   4.0 2019-01-02       Bank E
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 0          First Bank         Bank A         Zenith Bank  90000.0
# 10         Union Bank         Bank B              GTBank  54000.0
#
#    trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# 0           IKEJA      77088.0    Sobee        0.01            900
# 10          LEKKI      77088.0    Sobee        0.01            540

# %%
#top customer with the highest volume at sobee

customer_with_the_highest_volume_in_sobee =(customer_highest_v_per_customer['Amount']> 500000)

# %%
customer_highest_v_per_customer.loc[customer_with_the_highest_volume_in_sobee, ['Amount', 'Payer BVN', 'MERCHANT',]]
# Out:
#        Amount     Payer BVN MERCHANT
# 443  670000.0  2.222222e+10    Sobee

# %% [markdown]
# # NIBSS QUESTION 2a

# %% [markdown]
# # What customer transacted with the same merchant then most?

# %%
transaction_per_customer = nib.groupby(['Payer BVN'])
transaction_per_customer= transaction_per_customer.get_group('2.222222e+10')
transaction_per_customer.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-7610675a2a1d> in <module>()
#       1 transaction_per_customer = nib.groupby(['Payer BVN'])
# ----> 2 transaction_per_customer= transaction_per_customer.get_group('2.222222e+10')
#       3 transaction_per_customer.head(2)
#
# C:\Users\ericksen\Anaconda2anacon\lib\site-packages\pandas\core\groupby\groupby.pyc in get_group(self, name, obj)
#     646         inds = self._get_index(name)
#     647         if not len(inds):
# --> 648             raise KeyError(name)
#     649
#     650         return obj._take(inds, axis=self.axis)
#
# KeyError: '2.222222e+10'

# %%
nib['MERCHANT'].value_counts()
# Out:
# Shporite          70
# NY Supermarket    70
# Renee             70
# Sobee             66
# Spar              51
# Grand Square      39
# Game              30
# FastMart          30
# Ebano             24
# Daytona           24
# Name: MERCHANT, dtype: int64

# %%
nib['Issuing Banks Name'].value_counts()
# Out:
# GTBank           77
# Zenith Bank      59
# Union Bank       56
# UBA              55
# Fidelity Bank    52
# EcoBank          49
# First Bank       41
# FCMB             38
# Unity Bank       24
# Access Bank      23
# Name: Issuing Banks Name, dtype: int64

# %% [markdown]
# # On what day did we have the most transactions?

# %%
day_highest =(nib['Amount']> 7000000)
nib.loc[day_highest, ['Amount', 'Date', 'trans_location', 'MERCHANT',]]
# Out:
#          Amount       Date trans_location  MERCHANT
# 147  12000000.0 2019-01-31          IKEJA     Renee
# 187   8000000.0 2019-02-02          IKOYI  FastMart

# %% [markdown]
# # How many banks does (customer) operate?

# %%
customer_bank = nib.groupby(['Issuing Banks Name'])
customer_bank= customer_bank.get_group('First Bank')
customer_bank.head()
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 0   11132019.0  2.222222e+10                   5.0 2019-01-01       bank F
# 2   11132005.0  2.222222e+10                   5.0 2019-01-01       bank F
# 11  11131942.0  2.222222e+10                   4.0 2019-01-02       Bank F
# 35  11131774.0  2.222222e+10                   4.0 2019-01-05       Bank F
# 36  11131767.0  2.222222e+10                   4.0 2019-01-05       Bank F
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name   Amount  \
# 0          First Bank         Bank A         Zenith Bank  90000.0
# 2          First Bank         Bank B              GTBank  13800.0
# 11         First Bank         Bank B              GTBank   7000.0
# 35         First Bank         Bank A         Zenith Bank  80000.0
# 36         First Bank         Bank A         Zenith Bank  45000.0
#
#    trans_location  Terminal Id MERCHANT  NIBBS RATE NIBBS COMMISION
# ...

# %%
customer_bank['Payer BVN'].value_counts()
# Out:
# 2.222222e+10    5
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    3
# 2.222222e+10    3
# 2.222222e+10    3
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    1
# Name: Payer BVN, dtype: int64

# %%
5+4+4+4+4+4+3+3+3+2+2+2+1
# Out:
# 41

# %%
customer_bank_zenith = nib.groupby(['Issuing Banks Name'])
customer_bank_zenith= customer_bank_zenith.get_group('Zenith Bank')
customer_bank_zenith.head()
# Out:
#           Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 1  11132012.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 3  11131998.0  2.222222e+10                   4.0 2019-01-01       bank A
# 4  11131991.0  2.222222e+10                   4.0 2019-01-01       Bank A
# 5  11131984.0  2.222222e+10                   4.0 2019-01-01       bank A
# 6  11131977.0  2.222222e+10                   4.0 2019-01-01       Bank A
#
#   Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 1        Zenith Bank         Bank B              GTBank   12750.0
# 3        Zenith Bank         Bank B              GTBank  670000.0
# 4        Zenith Bank         Bank B              GTBank  220000.0
# 5        Zenith Bank         Bank B              GTBank  350000.0
# 6        Zenith Bank         Bank B              GTBank   23000.0
#
#     trans_location  Terminal Id      MERCHANT  NIBBS RATE NIBBS COMMISION
# ...

# %%
customer_bank_zenith['Payer BVN'].value_counts()
# Out:
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    4
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# Name: Payer BVN, dtype: int64

# %% [markdown]
# # What receiving Bank is most used by the customer?

# %%
recieving_bank = nib.groupby(['Receiving Bank'])
recieving_bank = recieving_bank.get_group('Bank G')
recieving_bank.head()
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 44  11131711.0  2.222222e+10                   4.0 2019-01-07       Bank B
# 48  11131683.0  2.222222e+10                   4.0 2019-01-08       Bank J
# 52  11131655.0  2.222222e+10                   4.0 2019-01-09       Bank B
# 55  11131634.0  2.222222e+10                   4.0 2019-01-09       Bank D
# 59  11131606.0  2.222222e+10                   4.0 2019-01-10       Bank D
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name     Amount  \
# 44             GTBank         Bank G          Unity Bank   130000.0
# 48               FCMB         Bank G          Unity Bank  1500000.0
# 52             GTBank         Bank G          Unity Bank     2100.0
# 55            EcoBank         Bank G          Unity Bank    45000.0
# 59            EcoBank         Bank G          Unity Bank  2500000.0
#
#    trans_location  Terminal Id        MERCHANT  NIBBS RATE NIBBS COMMISION
# ...

# %%
recieving_bank['Receiving Bank'].value_counts()
# Out:
# Bank G    167
# Name: Receiving Bank, dtype: int64

# %%
recieving_bank['NIBBS RATE'].value_counts()
# Out:
# 0.01    167
# Name: NIBBS RATE, dtype: int64

# %%
recieving_ban = nib.groupby(['Receiving Bank'])
recieving_ban = recieving_ban.get_group('Bank j')
recieving_ban.head()
# Out:
#            Tid     Payer BVN  BVN/PER TRANSACTIONS       Date Issuing Bank  \
# 47  11131690.0  2.222222e+10                   4.0 2019-01-08       Bank J
# 51  11131662.0  2.222222e+10                   4.0 2019-01-09       Bank B
# 58  11131613.0  2.222222e+10                   4.0 2019-01-10       Bank D
# 62  11131585.0  2.222222e+10                   4.0 2019-01-11       Bank B
# 70  11131529.0  2.222222e+10                   4.0 2019-01-13       Bank E
#
#    Issuing Banks Name Receiving Bank Receiving Bank Name    Amount  \
# 47               FCMB         Bank j                FCMB  500000.0
# 51             GTBank         Bank j                FCMB  125000.0
# 58            EcoBank         Bank j                FCMB  890000.0
# 62             GTBank         Bank j                FCMB   45000.0
# 70         Union Bank         Bank j                FCMB   13800.0
#
#      trans_location  Terminal Id      MERCHANT  NIBBS RATE NIBBS COMMISION
# ...

# %%
recieving_ban['Payer BVN'].value_counts()
# Out:
# 2.222222e+10    3
# 2.222222e+10    3
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    2
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
#                ..
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# 2.222222e+10    1
# ...

# %%
day_h =(nib['Amount']> 700000)
nib.loc[day_h, ['Amount', 'Date', 'trans_location', 'MERCHANT',]]
# Out:
#          Amount       Date   trans_location        MERCHANT
# 14     709680.0 2019-01-02  VICTORIA ISLAND        Shporite
# 18     780000.0 2019-01-03            LEKKI           Renee
# 19     789000.0 2019-01-03         MARYLAND        Shporite
# 48    1500000.0 2019-01-08            LEKKI  NY Supermarket
# 58     890000.0 2019-01-10  VICTORIA ISLAND            Spar
# 59    2500000.0 2019-01-10             YABA    Grand Square
# 60    4000000.0 2019-01-10         MARYLAND  NY Supermarket
# 82     709680.0 2019-01-16  VICTORIA ISLAND  NY Supermarket
# 86     780000.0 2019-01-17  VICTORIA ISLAND  NY Supermarket
# 87     789000.0 2019-01-18  VICTORIA ISLAND           Renee
# 116   1500000.0 2019-01-26            IKEJA         Daytona
# 126    890000.0 2019-01-27            LEKKI         Daytona
# 127   2500000.0 2019-01-27            IKOYI           Ebano
# 128   4000000.0 2019-01-28            IKEJA        FastMart
# 138    900000.0 2019-01-29            IKEJA        Shporite
# ...

# %% [markdown]
# # What bank received the highest volume of transactions?

# %%
merchant_locat =(nib['Amount']> 7000000)
nib.loc[merchant_locat, ['Amount', 'trans_location', 'MERCHANT', 'Receiving Bank Name']]
# Out:
#          Amount trans_location  MERCHANT Receiving Bank Name
# 147  12000000.0          IKEJA     Renee         Access Bank
# 187   8000000.0          IKOYI  FastMart          Unity Bank

# %%
merchant_loca =(nib['Amount']> 7000000)
nib.loc[merchant_loca, ['Amount', 'Payer BVN', 'MERCHANT', 'Receiving Bank Name', 'Date']]
# Out:
#          Amount     Payer BVN  MERCHANT Receiving Bank Name       Date
# 147  12000000.0  2.222222e+10     Renee         Access Bank 2019-01-31
# 187   8000000.0  2.222222e+10  FastMart          Unity Bank 2019-02-02

# %%
In February show Top 5 merchants by total volume of transaction?

# %%
#nib['Date'].dt.month_name()

# %%
#nib['Date'].dt.day_name()
