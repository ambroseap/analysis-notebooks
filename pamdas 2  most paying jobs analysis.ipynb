# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
from numpy.random import randn

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 85)

# %%
pd.set_option('display.max_rows', 85)

# %%
pub_df = pd.read_csv('public.csv')

# %%
pub_df
# Out:
#        Unnamed: 0  RESPONDENT HOBBYIST  \
# 0               0           1      Yes
# 1               1           2       No
# 2               2           3      Yes
# 3               3           4       No
# 4               4           5      Yes
# 5               5           6      Yes
# 6               6           7       No
# 7               7           8      Yes
# 8               8           9      Yes
# 9              10          11      Yes
# 10             12          13      Yes
# 11             13          14      Yes
# 12             14          15      Yes
# 13             15          16      Yes
# 14             16          17      Yes
# 15             17          18      Yes
# 16             18          19      Yes
# 17             19          20       No
# 18             20          21      Yes
# 19             21          22      Yes
# 20             22          23      Yes
# 21             23          24      Yes
# 22             24          25       No
# 23             25          26      Yes
# 24             26          27      Yes
# 25             27          28      Yes
# 26             28          29      Yes
# 27             29          30       No
# 28             31          32       No
# 29             32          33       No
# 30             33          34      Yes
# 31             35          36      Yes
# 32             36          37      Yes
# 33             37          38      Yes
# 34             38          39      Yes
# 35             39          40      Yes
# 36             41          42      Yes
# 37             42          43      Yes
# 38             43          44      Yes
# 39             44          45      Yes
# 40             45          46      Yes
# 41             46          47      Yes
# ...           ...         ...      ...
# 77877       88786       72325      Yes
# 77878       88787       72492      Yes
# 77879       88794       73695      Yes
# 77880       88797       74976      Yes
# 77881       88801       75496      Yes
# 77882       88803       75842      Yes
# 77883       88804       75974      Yes
# 77884       88805       76444       No
# 77885       88806       76822       No
# 77886       88811       77920      Yes
# 77887       88813       77968       No
# 77888       88818       78292       No
# 77889       88819       78326      Yes
# 77890       88822       79354       No
# 77891       88823       79616       No
# 77892       88825       79795      Yes
# 77893       88826       79798      Yes
# 77894       88828       80116       No
# 77895       88829       80319      Yes
# 77896       88836       81934      Yes
# 77897       88839       82134      Yes
# 77898       88840       82717       No
# 77899       88841       82789      Yes
# 77900       88842       82805      Yes
# 77901       88843       83000       No
# 77902       88850       83786       No
# 77903       88852       83862      Yes
# 77904       88857       85396       No
# 77905       88860       85738      Yes
# 77906       88862       85955      Yes
# 77907       88863       85961      Yes
# 77908       88864       86012      Yes
# 77909       88865       86566      Yes
# 77910       88866       86638      Yes
# 77911       88867       86806      Yes
# 77912       88870       87352      Yes
# 77913       88871       87386      Yes
# 77914       88875       88182      Yes
# 77915       88876       88212       No
# 77916       88877       88282      Yes
# 77917       88878       88377      Yes
# 77918       88882       88863      Yes
#
#                                              OPENSOURCER  \
# 0                                                  Never
# 1                                Less than once per year
# 2                                                  Never
# 3                                                  Never
# 4                             Once a month or more often
# 5                                                  Never
# 6                                                  Never
# 7                                Less than once per year
# 8                             Once a month or more often
# 9                             Once a month or more often
# 10     Less than once a month but more than once per ...
# 11                               Less than once per year
# 12                                                 Never
# 13                                                 Never
# 14     Less than once a month but more than once per ...
# 15     Less than once a month but more than once per ...
# 16                                                 Never
# 17                                                 Never
# 18                            Once a month or more often
# 19                               Less than once per year
# 20                               Less than once per year
# 21                                                 Never
# 22                                                 Never
# 23                               Less than once per year
# 24                               Less than once per year
# 25                               Less than once per year
# 26     Less than once a month but more than once per ...
# 27     Less than once a month but more than once per ...
# 28                                                 Never
# 29     Less than once a month but more than once per ...
# 30                                                 Never
# 31     Less than once a month but more than once per ...
# 32                               Less than once per year
# 33                                                 Never
# 34                               Less than once per year
# 35                                                 Never
# 36     Less than once a month but more than once per ...
# 37                               Less than once per year
# 38                            Once a month or more often
# 39                                                 Never
# 40                               Less than once per year
# 41                               Less than once per year
# ...                                                  ...
# 77877                         Once a month or more often
# 77878                         Once a month or more often
# 77879                            Less than once per year
# 77880  Less than once a month but more than once per ...
# 77881                            Less than once per year
# 77882                            Less than once per year
# 77883                         Once a month or more often
# 77884                         Once a month or more often
# 77885  Less than once a month but more than once per ...
# 77886  Less than once a month but more than once per ...
# 77887                            Less than once per year
# 77888                         Once a month or more often
# 77889                         Once a month or more often
# 77890                            Less than once per year
# 77891                         Once a month or more often
# 77892  Less than once a month but more than once per ...
# 77893  Less than once a month but more than once per ...
# 77894                            Less than once per year
# 77895                                              Never
# 77896  Less than once a month but more than once per ...
# 77897                                              Never
# 77898                            Less than once per year
# 77899                         Once a month or more often
# 77900  Less than once a month but more than once per ...
# 77901                            Less than once per year
# 77902                         Once a month or more often
# 77903                         Once a month or more often
# 77904  Less than once a month but more than once per ...
# 77905                                              Never
# 77906                            Less than once per year
# 77907                            Less than once per year
# 77908                         Once a month or more often
# 77909  Less than once a month but more than once per ...
# 77910                                              Never
# 77911                         Once a month or more often
# 77912                            Less than once per year
# 77913  Less than once a month but more than once per ...
# 77914                         Once a month or more often
# 77915                            Less than once per year
# 77916                         Once a month or more often
# 77917  Less than once a month but more than once per ...
# 77918                            Less than once per year
#
#                                               OPENSOURCE  \
# 0      The quality of OSS and closed source software ...
# 1      The quality of OSS and closed source software ...
# 2      The quality of OSS and closed source software ...
# 3      The quality of OSS and closed source software ...
# 4      OSS is, on average, of HIGHER quality than pro...
# 5      The quality of OSS and closed source software ...
# 6      The quality of OSS and closed source software ...
# 7      OSS is, on average, of HIGHER quality than pro...
# 8      The quality of OSS and closed source software ...
# 9      The quality of OSS and closed source software ...
# 10     OSS is, on average, of HIGHER quality than pro...
# 11     The quality of OSS and closed source software ...
# 12     OSS is, on average, of HIGHER quality than pro...
# 13     The quality of OSS and closed source software ...
# 14     The quality of OSS and closed source software ...
# 15     The quality of OSS and closed source software ...
# 16     The quality of OSS and closed source software ...
# 17     OSS is, on average, of HIGHER quality than pro...
# 18     OSS is, on average, of HIGHER quality than pro...
# 19     OSS is, on average, of HIGHER quality than pro...
# 20     The quality of OSS and closed source software ...
# 21     OSS is, on average, of HIGHER quality than pro...
# 22     OSS is, on average, of HIGHER quality than pro...
# 23     The quality of OSS and closed source software ...
# 24     OSS is, on average, of HIGHER quality than pro...
# 25     The quality of OSS and closed source software ...
# 26     OSS is, on average, of HIGHER quality than pro...
# 27     OSS is, on average, of HIGHER quality than pro...
# 28     The quality of OSS and closed source software ...
# 29     OSS is, on average, of HIGHER quality than pro...
# 30     OSS is, on average, of HIGHER quality than pro...
# 31     The quality of OSS and closed source software ...
# 32     OSS is, on average, of LOWER quality than prop...
# 33     OSS is, on average, of LOWER quality than prop...
# 34     The quality of OSS and closed source software ...
# 35     OSS is, on average, of HIGHER quality than pro...
# 36     OSS is, on average, of HIGHER quality than pro...
# 37     OSS is, on average, of HIGHER quality than pro...
# 38     The quality of OSS and closed source software ...
# 39     The quality of OSS and closed source software ...
# 40     OSS is, on average, of HIGHER quality than pro...
# 41     OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 77877  OSS is, on average, of HIGHER quality than pro...
# 77878  The quality of OSS and closed source software ...
# 77879  OSS is, on average, of HIGHER quality than pro...
# 77880  The quality of OSS and closed source software ...
# 77881  The quality of OSS and closed source software ...
# 77882  OSS is, on average, of LOWER quality than prop...
# 77883  OSS is, on average, of HIGHER quality than pro...
# 77884  OSS is, on average, of LOWER quality than prop...
# 77885  OSS is, on average, of HIGHER quality than pro...
# 77886                                                NaN
# 77887  The quality of OSS and closed source software ...
# 77888  OSS is, on average, of HIGHER quality than pro...
# 77889                                                NaN
# 77890  The quality of OSS and closed source software ...
# 77891  OSS is, on average, of HIGHER quality than pro...
# 77892  OSS is, on average, of HIGHER quality than pro...
# 77893  OSS is, on average, of HIGHER quality than pro...
# 77894                                                NaN
# 77895  OSS is, on average, of HIGHER quality than pro...
# 77896  OSS is, on average, of HIGHER quality than pro...
# 77897                                                NaN
# 77898  The quality of OSS and closed source software ...
# 77899  The quality of OSS and closed source software ...
# 77900  The quality of OSS and closed source software ...
# 77901  OSS is, on average, of HIGHER quality than pro...
# 77902  The quality of OSS and closed source software ...
# 77903  OSS is, on average, of HIGHER quality than pro...
# 77904  OSS is, on average, of HIGHER quality than pro...
# 77905  The quality of OSS and closed source software ...
# 77906  OSS is, on average, of LOWER quality than prop...
# 77907  The quality of OSS and closed source software ...
# 77908  OSS is, on average, of HIGHER quality than pro...
# 77909  OSS is, on average, of HIGHER quality than pro...
# 77910  OSS is, on average, of HIGHER quality than pro...
# 77911  OSS is, on average, of HIGHER quality than pro...
# 77912                                                NaN
# 77913  OSS is, on average, of LOWER quality than prop...
# 77914  OSS is, on average, of HIGHER quality than pro...
# 77915  OSS is, on average, of HIGHER quality than pro...
# 77916  The quality of OSS and closed source software ...
# 77917  The quality of OSS and closed source software ...
# 77918  OSS is, on average, of HIGHER quality than pro...
#
#                                               EMPLOYMENT         STUDENT  \
# 0                 Not employed, and not looking for work              No
# 1                     Not employed, but looking for work  Yes, full-time
# 2                                     Employed full-time              No
# 3                                     Employed full-time              No
# 4                                     Employed full-time              No
# 5                                     Employed full-time              No
# 6      Independent contractor, freelancer, or self-em...              No
# 7                     Not employed, but looking for work             NaN
# 8                                     Employed full-time              No
# 9                                                    NaN  Yes, full-time
# 10                                    Employed full-time              No
# 11                                    Employed full-time              No
# 12                    Not employed, but looking for work  Yes, full-time
# 13                                    Employed full-time              No
# 14                                    Employed full-time              No
# 15                                    Employed full-time              No
# 16                                    Employed full-time              No
# 17                                    Employed full-time              No
# 18                                                   NaN             NaN
# 19                                    Employed full-time              No
# 20                                    Employed full-time              No
# 21                                    Employed full-time              No
# 22                                    Employed full-time              No
# 23                                    Employed full-time              No
# 24                    Not employed, but looking for work  Yes, part-time
# 25                                    Employed full-time              No
# 26                                    Employed full-time              No
# 27                                    Employed full-time              No
# 28                                    Employed full-time              No
# 29                                    Employed full-time  Yes, full-time
# 30                    Not employed, but looking for work              No
# 31                                    Employed full-time  Yes, full-time
# 32                                    Employed part-time  Yes, full-time
# 33                                    Employed full-time              No
# 34                                    Employed full-time              No
# 35     Independent contractor, freelancer, or self-em...  Yes, full-time
# 36                                    Employed full-time              No
# 37                                    Employed full-time              No
# 38                                    Employed full-time              No
# 39                                    Employed full-time              No
# 40     Independent contractor, freelancer, or self-em...              No
# 41                                    Employed full-time              No
# ...                                                  ...             ...
# 77877  Independent contractor, freelancer, or self-em...              No
# 77878                 Not employed, but looking for work              No
# 77879                                 Employed full-time              No
# 77880                 Not employed, but looking for work              No
# 77881                                 Employed full-time              No
# 77882                                 Employed full-time  Yes, full-time
# 77883                                 Employed full-time              No
# 77884                                 Employed full-time  Yes, full-time
# 77885                                                NaN             NaN
# 77886                                 Employed full-time              No
# 77887  Independent contractor, freelancer, or self-em...              No
# 77888  Independent contractor, freelancer, or self-em...              No
# 77889                                                NaN              No
# 77890                 Not employed, but looking for work              No
# 77891                 Not employed, but looking for work              No
# 77892                                 Employed full-time              No
# 77893                                 Employed part-time  Yes, full-time
# 77894                                 Employed part-time              No
# 77895  Independent contractor, freelancer, or self-em...              No
# 77896             Not employed, and not looking for work              No
# 77897                                                NaN              No
# 77898                 Not employed, but looking for work              No
# 77899                                                NaN              No
# 77900  Independent contractor, freelancer, or self-em...              No
# 77901                                 Employed full-time              No
# 77902                                 Employed full-time              No
# 77903                                 Employed full-time  Yes, full-time
# 77904  Independent contractor, freelancer, or self-em...              No
# 77905             Not employed, and not looking for work  Yes, full-time
# 77906             Not employed, and not looking for work  Yes, part-time
# 77907                                                NaN              No
# 77908                                 Employed full-time              No
# 77909                                            Retired              No
# 77910             Not employed, and not looking for work              No
# 77911                                 Employed part-time  Yes, part-time
# 77912             Not employed, and not looking for work              No
# 77913  Independent contractor, freelancer, or self-em...  Yes, full-time
# 77914                                 Employed part-time             NaN
# 77915                                 Employed full-time              No
# 77916                 Not employed, but looking for work              No
# 77917             Not employed, and not looking for work              No
# 77918             Not employed, and not looking for work  Yes, full-time
#
#                                                  EDLEVEL  \
# 0                              Primary/elementary school
# 1      Secondary school (e.g. American high school, G...
# 2               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8      Some college/university study without earning ...
# 9                              Primary/elementary school
# 10           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11             Other doctoral degree (Ph.D, Ed.D., etc.)
# 12     Secondary school (e.g. American high school, G...
# 13           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 14              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 15           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 16     Some college/university study without earning ...
# 17           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 18                                                   NaN
# 19     Some college/university study without earning ...
# 20              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 21                             Primary/elementary school
# 22                                      Associate degree
# 23     Some college/university study without earning ...
# 24     Some college/university study without earning ...
# 25              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 26              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 27              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28                                      Associate degree
# 29           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 30                             Primary/elementary school
# 31     Secondary school (e.g. American high school, G...
# 32                                      Associate degree
# 33           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 34              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 35     Secondary school (e.g. American high school, G...
# 36     Secondary school (e.g. American high school, G...
# 37              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 38              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 39           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 40              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 41             Other doctoral degree (Ph.D, Ed.D., etc.)
# ...                                                  ...
# 77877  Secondary school (e.g. American high school, G...
# 77878  Some college/university study without earning ...
# 77879           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77880           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77881        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 77882           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77883           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77884           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77885                 Professional degree (JD, MD, etc.)
# 77886           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77887        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 77888          Other doctoral degree (Ph.D, Ed.D., etc.)
# 77889  Some college/university study without earning ...
# 77890                                   Associate degree
# 77891           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77892           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77893           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77894  Some college/university study without earning ...
# 77895  Secondary school (e.g. American high school, G...
# 77896        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 77897             I never completed any formal education
# 77898  Secondary school (e.g. American high school, G...
# 77899  Secondary school (e.g. American high school, G...
# 77900  Some college/university study without earning ...
# 77901  Secondary school (e.g. American high school, G...
# 77902          Other doctoral degree (Ph.D, Ed.D., etc.)
# 77903           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77904                 Professional degree (JD, MD, etc.)
# 77905  Secondary school (e.g. American high school, G...
# 77906  Secondary school (e.g. American high school, G...
# 77907          Other doctoral degree (Ph.D, Ed.D., etc.)
# 77908        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 77909  Some college/university study without earning ...
# 77910  Some college/university study without earning ...
# 77911  Secondary school (e.g. American high school, G...
# 77912           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77913           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77914  Secondary school (e.g. American high school, G...
# 77915  Secondary school (e.g. American high school, G...
# 77916  Some college/university study without earning ...
# 77917                          Primary/elementary school
# 77918                 Professional degree (JD, MD, etc.)
#
#                                           UNDERGRADMAJOR  \
# 0                                                    NaN
# 1                                                    NaN
# 2                          Web development or web design
# 3      Computer science, computer engineering, or sof...
# 4      Computer science, computer engineering, or sof...
# 5                              Mathematics or statistics
# 6      Another engineering discipline (ex. civil, ele...
# 7      Computer science, computer engineering, or sof...
# 8      Computer science, computer engineering, or sof...
# 9                                                    NaN
# 10     Computer science, computer engineering, or sof...
# 11     Computer science, computer engineering, or sof...
# 12                                                   NaN
# 13                                                   NaN
# 14     Computer science, computer engineering, or sof...
# 15     Computer science, computer engineering, or sof...
# 16     Computer science, computer engineering, or sof...
# 17     Information systems, information technology, o...
# 18                                                   NaN
# 19                                                   NaN
# 20     Information systems, information technology, o...
# 21                                                   NaN
# 22     Computer science, computer engineering, or sof...
# 23     Computer science, computer engineering, or sof...
# 24     Information systems, information technology, o...
# 25     A business discipline (ex. accounting, finance...
# 26                                                   NaN
# 27     Computer science, computer engineering, or sof...
# 28     Information systems, information technology, o...
# 29     A natural science (ex. biology, chemistry, phy...
# 30                                                   NaN
# 31                                                   NaN
# 32     A social science (ex. anthropology, psychology...
# 33     Computer science, computer engineering, or sof...
# 34     Computer science, computer engineering, or sof...
# 35                                                   NaN
# 36                                                   NaN
# 37     Computer science, computer engineering, or sof...
# 38     Information systems, information technology, o...
# 39     Another engineering discipline (ex. civil, ele...
# 40     Another engineering discipline (ex. civil, ele...
# 41     A humanities discipline (ex. literature, histo...
# ...                                                  ...
# 77877                                                NaN
# 77878                           I never declared a major
# 77879  Another engineering discipline (ex. civil, ele...
# 77880                          Mathematics or statistics
# 77881  Computer science, computer engineering, or sof...
# 77882  Computer science, computer engineering, or sof...
# 77883  Another engineering discipline (ex. civil, ele...
# 77884                           I never declared a major
# 77885  A health science (ex. nursing, pharmacy, radio...
# 77886  Computer science, computer engineering, or sof...
# 77887  Information systems, information technology, o...
# 77888  A health science (ex. nursing, pharmacy, radio...
# 77889  Computer science, computer engineering, or sof...
# 77890                           I never declared a major
# 77891                          Mathematics or statistics
# 77892  Computer science, computer engineering, or sof...
# 77893  Computer science, computer engineering, or sof...
# 77894                                                NaN
# 77895                                                NaN
# 77896  Computer science, computer engineering, or sof...
# 77897                                                NaN
# 77898                                                NaN
# 77899                                                NaN
# 77900                           I never declared a major
# 77901                                                NaN
# 77902  Computer science, computer engineering, or sof...
# 77903                                                NaN
# 77904                                                NaN
# 77905                                                NaN
# 77906                                                NaN
# 77907  Computer science, computer engineering, or sof...
# 77908  Another engineering discipline (ex. civil, ele...
# 77909  A humanities discipline (ex. literature, histo...
# 77910  Computer science, computer engineering, or sof...
# 77911                                                NaN
# 77912  Computer science, computer engineering, or sof...
# 77913  Computer science, computer engineering, or sof...
# 77914                                                NaN
# 77915                                                NaN
# 77916  Computer science, computer engineering, or sof...
# 77917                                                NaN
# 77918  Computer science, computer engineering, or sof...
#
#                                                 EDUOTHER  \
# 0      Taught yourself a new language, framework, or ...
# 1      Taken an online course in programming or softw...
# 2      Taught yourself a new language, framework, or ...
# 3      Taken an online course in programming or softw...
# 4      Taken an online course in programming or softw...
# 5      Taken an online course in programming or softw...
# 6      Taught yourself a new language, framework, or ...
# 7      Taught yourself a new language, framework, or ...
# 8      Taken an online course in programming or softw...
# 9                    Contributed to open source software
# 10     Taken an online course in programming or softw...
# 11     Completed an industry certification program (e...
# 12     Taken an online course in programming or softw...
# 13     Taken an online course in programming or softw...
# 14     Taken an online course in programming or softw...
# 15     Taken an online course in programming or softw...
# 16     Received on-the-job training in software devel...
# 17     Taken an online course in programming or softw...
# 18     Taught yourself a new language, framework, or ...
# 19     Taken an online course in programming or softw...
# 20     Taken an online course in programming or softw...
# 21     Taken an online course in programming or softw...
# 22     Taken an online course in programming or softw...
# 23     Taught yourself a new language, framework, or ...
# 24     Taken an online course in programming or softw...
# 25     Taken an online course in programming or softw...
# 26     Taken an online course in programming or softw...
# 27     Taught yourself a new language, framework, or ...
# 28     Completed an industry certification program (e...
# 29     Taken an online course in programming or softw...
# 30     Taken an online course in programming or softw...
# 31     Taken an online course in programming or softw...
# 32     Taken a part-time in-person course in programm...
# 33     Participated in a full-time developer training...
# 34     Taken an online course in programming or softw...
# 35     Taken an online course in programming or softw...
# 36     Taken a part-time in-person course in programm...
# 37     Taken an online course in programming or softw...
# 38     Taken an online course in programming or softw...
# 39     Received on-the-job training in software devel...
# 40     Taken an online course in programming or softw...
# 41     Taken an online course in programming or softw...
# ...                                                  ...
# 77877  Taken an online course in programming or softw...
# 77878  Taught yourself a new language, framework, or ...
# 77879  Taken an online course in programming or softw...
# 77880  Taken an online course in programming or softw...
# 77881  Taken an online course in programming or softw...
# 77882  Taken an online course in programming or softw...
# 77883  Taught yourself a new language, framework, or ...
# 77884  Participated in online coding competitions (e....
# 77885                                                NaN
# 77886  Taken an online course in programming or softw...
# 77887  Taken a part-time in-person course in programm...
# 77888  Completed an industry certification program (e...
# 77889  Taken an online course in programming or softw...
# 77890  Taken an online course in programming or softw...
# 77891  Taken an online course in programming or softw...
# 77892  Taken an online course in programming or softw...
# 77893  Taught yourself a new language, framework, or ...
# 77894  Taught yourself a new language, framework, or ...
# 77895  Taught yourself a new language, framework, or ...
# 77896  Taken an online course in programming or softw...
# 77897                                                NaN
# 77898                                                NaN
# 77899  Taken an online course in programming or softw...
# 77900  Taken an online course in programming or softw...
# 77901  Taken an online course in programming or softw...
# 77902  Taught yourself a new language, framework, or ...
# 77903                        Participated in a hackathon
# 77904  Taken an online course in programming or softw...
# 77905  Taught yourself a new language, framework, or ...
# 77906  Taught yourself a new language, framework, or ...
# 77907  Taught yourself a new language, framework, or ...
# 77908  Taught yourself a new language, framework, or ...
# 77909  Taken a part-time in-person course in programm...
# 77910                                                NaN
# 77911                Contributed to open source software
# 77912                                                NaN
# 77913  Taken an online course in programming or softw...
# 77914  Taken an online course in programming or softw...
# 77915  Taught yourself a new language, framework, or ...
# 77916  Taught yourself a new language, framework, or ...
# 77917  Taught yourself a new language, framework, or ...
# 77918  Taken an online course in programming or softw...
#
#                                                  ORGSIZE  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                   100 to 499 employees
# 3                                   100 to 499 employees
# 4                               10,000 or more employees
# 5                                                    NaN
# 6      Just me - I am a freelancer, sole proprietor, ...
# 7                                                    NaN
# 8                                     10 to 19 employees
# 9                                                    NaN
# 10                                    10 to 19 employees
# 11                                  100 to 499 employees
# 12                                                   NaN
# 13                                  100 to 499 employees
# 14                                    20 to 99 employees
# 15                              1,000 to 4,999 employees
# 16                                  100 to 499 employees
# 17                              1,000 to 4,999 employees
# 18                                                   NaN
# 19                              10,000 or more employees
# 20                              10,000 or more employees
# 21                                    10 to 19 employees
# 22                                         2-9 employees
# 23                              10,000 or more employees
# 24                                                   NaN
# 25                                         2-9 employees
# 26                              10,000 or more employees
# 27                              1,000 to 4,999 employees
# 28                                  100 to 499 employees
# 29                              10,000 or more employees
# 30                                                   NaN
# 31                              1,000 to 4,999 employees
# 32                                  100 to 499 employees
# 33                                    10 to 19 employees
# 34                                  100 to 499 employees
# 35                                                   NaN
# 36     Just me - I am a freelancer, sole proprietor, ...
# 37                              10,000 or more employees
# 38                              10,000 or more employees
# 39                              1,000 to 4,999 employees
# 40     Just me - I am a freelancer, sole proprietor, ...
# 41                                  100 to 499 employees
# ...                                                  ...
# 77877  Just me - I am a freelancer, sole proprietor, ...
# 77878                                                NaN
# 77879                               500 to 999 employees
# 77880                                                NaN
# 77881                           10,000 or more employees
# 77882                                 20 to 99 employees
# 77883                           1,000 to 4,999 employees
# 77884                                                NaN
# 77885                                                NaN
# 77886                           1,000 to 4,999 employees
# 77887                                      2-9 employees
# 77888  Just me - I am a freelancer, sole proprietor, ...
# 77889                                                NaN
# 77890                                                NaN
# 77891                                                NaN
# 77892                               500 to 999 employees
# 77893                                 10 to 19 employees
# 77894                                                NaN
# 77895  Just me - I am a freelancer, sole proprietor, ...
# 77896                                                NaN
# 77897                                                NaN
# 77898                                                NaN
# 77899                                                NaN
# 77900  Just me - I am a freelancer, sole proprietor, ...
# 77901                               100 to 499 employees
# 77902                               500 to 999 employees
# 77903                                                NaN
# 77904                               100 to 499 employees
# 77905                                                NaN
# 77906                                                NaN
# 77907                                                NaN
# 77908                               100 to 499 employees
# 77909                                                NaN
# 77910                                                NaN
# 77911  Just me - I am a freelancer, sole proprietor, ...
# 77912                                                NaN
# 77913                                                NaN
# 77914                                 10 to 19 employees
# 77915                                 10 to 19 employees
# 77916                                                NaN
# 77917                                                NaN
# 77918                                                NaN
#
#                                                  DEVTYPE           YEARSCODE  \
# 0                                                    NaN                   4
# 1      Developer, desktop or enterprise applications;...                 NaN
# 2      Designer;Developer, back-end;Developer, front-...                   3
# 3                                  Developer, full-stack                   3
# 4      Academic researcher;Developer, desktop or ente...                  16
# 5      Data or business analyst;Data scientist or mac...                  13
# 6                          Designer;Developer, front-end                   6
# 7         Developer, back-end;Engineer, site reliability                   8
# 8      Database administrator;Developer, back-end;Dev...                  12
# 9                                                    NaN                   2
# 10     Data or business analyst;Database administrato...                  17
# 11         Developer, desktop or enterprise applications                  13
# 12                                               Student                   3
# 13                                 Developer, full-stack                  10
# 14     Developer, back-end;Developer, front-end;Devel...                   5
# 15                              Data or business analyst                  10
# 16                                 Developer, full-stack                  14
# 17     Database administrator;Designer;Developer, bac...                   8
# 18                                                   NaN                   5
# 19     Data or business analyst;Designer;Developer, b...                  35
# 20                                 Developer, full-stack                   3
# 21                                  Developer, front-end                   2
# 22     Designer;Developer, back-end;Developer, front-...                   2
# 23     Designer;Developer, back-end;Developer, deskto...                  12
# 24     Developer, back-end;Developer, front-end;Devel...                   7
# 25     Designer;Developer, front-end;Developer, full-...                  10
# 26                         Developer, front-end;Educator                   4
# 27          DevOps specialist;Engineer, site reliability                   6
# 28                                 Developer, full-stack                   3
# 29     Academic researcher;Data scientist or machine ...                   6
# 30                                 Developer, full-stack    Less than 1 year
# 31                             Developer, mobile;Student                  10
# 32                                               Student                   7
# 33                  Developer, full-stack;Engineer, data                  30
# 34     Database administrator;Developer, back-end;Dev...                  30
# 35     Developer, back-end;Developer, full-stack;Student                   5
# 36     Academic researcher;Data or business analyst;D...                   8
# 37     Developer, front-end;Developer, game or graphi...                   9
# 38     Developer, back-end;Developer, desktop or ente...                  26
# 39                                   Engineering manager                  40
# 40                  Developer, full-stack;Engineer, data                  19
# 41                                   Engineering manager                  35
# ...                                                  ...                 ...
# 77877  Academic researcher;Data scientist or machine ...                   9
# 77878  Developer, back-end;Developer, desktop or ente...                   7
# 77879                           Data or business analyst    Less than 1 year
# 77880                                                NaN                 NaN
# 77881                                  DevOps specialist                   7
# 77882                              Developer, full-stack                   4
# 77883  Developer, full-stack;DevOps specialist;Engine...                  20
# 77884  Developer, back-end;Developer, desktop or ente...                   3
# 77885                                                NaN                   3
# 77886                              Developer, full-stack                  20
# 77887  Data or business analyst;Data scientist or mac...                   3
# 77888                                Academic researcher                  42
# 77889                                                NaN                  14
# 77890      Developer, back-end;Developer, mobile;Student                   3
# 77891    Marketing or sales professional;Product manager                 NaN
# 77892                              Developer, QA or test                   6
# 77893  Data or business analyst;Data scientist or mac...                   9
# 77894                                                NaN                   1
# 77895  Database administrator;Designer;Developer, bac...                   5
# 77896                                                NaN                  20
# 77897                                                NaN                   5
# 77898                                                NaN    Less than 1 year
# 77899                                                NaN                   9
# 77900  Developer, QA or test;Student;System administr...                   1
# 77901  DevOps specialist;Engineer, site reliability;S...                   7
# 77902                                Academic researcher                  36
# 77903                   Data or business analyst;Student                   1
# 77904                                Senior executive/VP                   4
# 77905                                                NaN                  10
# 77906                                                NaN                   4
# 77907                                                NaN                  24
# 77908                       Academic researcher;Educator                   5
# 77909                                                NaN  More than 50 years
# 77910                                                NaN                  16
# 77911                                Academic researcher                   5
# 77912                                                NaN                  40
# 77913                                            Student                  10
# 77914                                Academic researcher                   1
# 77915  Designer;Developer, front-end;Developer, full-...                  18
# 77916  Developer, back-end;Developer, desktop or ente...                  38
# 77917                                                NaN                 NaN
# 77918                                                NaN                   8
#
# ...
# 3                              Straight / Heterosexual
# 4                              Straight / Heterosexual
# 5                              Straight / Heterosexual
# 6                              Straight / Heterosexual
# 7                              Straight / Heterosexual
# 8                                             Bisexual
# 9      Bisexual;Gay or Lesbian;Straight / Heterosexual
# 10                             Straight / Heterosexual
# 11                             Straight / Heterosexual
# 12                                                 NaN
# 13                             Straight / Heterosexual
# 14                             Straight / Heterosexual
# 15                             Straight / Heterosexual
# 16                             Straight / Heterosexual
# 17                             Straight / Heterosexual
# 18                                                 NaN
# 19                             Straight / Heterosexual
# 20                             Straight / Heterosexual
# 21                             Straight / Heterosexual
# 22                             Straight / Heterosexual
# 23                                      Gay or Lesbian
# 24                             Straight / Heterosexual
# 25                                                 NaN
# 26                             Straight / Heterosexual
# 27                             Straight / Heterosexual
# 28                             Straight / Heterosexual
# 29                             Straight / Heterosexual
# 30                                            Bisexual
# 31                             Straight / Heterosexual
# 32                                                 NaN
# 33                                                 NaN
# 34                                            Bisexual
# 35                             Bisexual;Gay or Lesbian
# 36                             Straight / Heterosexual
# 37                             Straight / Heterosexual
# 38                             Straight / Heterosexual
# 39                             Straight / Heterosexual
# 40                             Straight / Heterosexual
# 41                             Straight / Heterosexual
# ...                                                ...
# 77877                                              NaN
# 77878                          Bisexual;Gay or Lesbian
# 77879                          Straight / Heterosexual
# 77880                                   Gay or Lesbian
# 77881                          Straight / Heterosexual
# 77882                                              NaN
# 77883                                              NaN
# 77884                                              NaN
# 77885                          Straight / Heterosexual
# 77886                          Straight / Heterosexual
# 77887                          Straight / Heterosexual
# 77888                          Straight / Heterosexual
# 77889                 Bisexual;Straight / Heterosexual
# 77890                          Straight / Heterosexual
# 77891                                              NaN
# 77892                          Straight / Heterosexual
# 77893                          Straight / Heterosexual
# 77894                          Straight / Heterosexual
# 77895                          Straight / Heterosexual
# 77896                          Straight / Heterosexual
# 77897                                              NaN
# 77898                          Straight / Heterosexual
# 77899                          Straight / Heterosexual
# 77900                          Straight / Heterosexual
# 77901                          Straight / Heterosexual
# 77902                                              NaN
# 77903                          Straight / Heterosexual
# 77904                          Straight / Heterosexual
# 77905                          Straight / Heterosexual
# 77906                                              NaN
# 77907                                   Gay or Lesbian
# 77908                                              NaN
# 77909                                              NaN
# 77910                          Straight / Heterosexual
# 77911                                              NaN
# 77912                                              NaN
# 77913                          Straight / Heterosexual
# 77914                          Straight / Heterosexual
# 77915                          Straight / Heterosexual
# 77916                          Straight / Heterosexual
# 77917                                              NaN
# 77918                          Straight / Heterosexual
#
#                                                ETHNICITY DEPENDENTS  \
# 0                                                    NaN         No
# 1                                                    NaN         No
# 2                                                    NaN        Yes
# 3                           White or of European descent         No
# 4               White or of European descent;Multiracial         No
# 5                                             East Asian         No
# 6                           White or of European descent        Yes
# 7                                                    NaN        NaN
# 8                           White or of European descent         No
# 9      Black or of African descent;East Asian;Hispani...         No
# 10                          White or of European descent        Yes
# 11                          White or of European descent         No
# 12                                                   NaN        Yes
# 13                          White or of European descent         No
# 14                 Hispanic or Latino/Latina;Multiracial         No
# 15                          White or of European descent        Yes
# 16                             Hispanic or Latino/Latina        Yes
# 17                          White or of European descent        Yes
# 18                                                   NaN         No
# 19                          White or of European descent        Yes
# 20                           Black or of African descent         No
# 21                                        Middle Eastern         No
# 22                          White or of European descent         No
# 23                                                   NaN         No
# 24                             Hispanic or Latino/Latina         No
# 25                                                   NaN        NaN
# 26                          White or of European descent        Yes
# 27                          White or of European descent         No
# 28                          White or of European descent         No
# 29                             Hispanic or Latino/Latina         No
# 30                                           South Asian        Yes
# 31                          White or of European descent         No
# 32                          White or of European descent         No
# 33                                                   NaN        Yes
# 34                          White or of European descent         No
# 35                          White or of European descent         No
# 36                                        Middle Eastern        NaN
# 37                             Hispanic or Latino/Latina         No
# 38                          White or of European descent        Yes
# 39                          White or of European descent         No
# 40                          White or of European descent         No
# 41                          White or of European descent        Yes
# ...                                                  ...        ...
# 77877                       White or of European descent         No
# 77878                          Hispanic or Latino/Latina         No
# 77879                                                NaN         No
# 77880                       White or of European descent         No
# 77881                                        South Asian        NaN
# 77882                                                NaN        NaN
# 77883                                     Middle Eastern        Yes
# 77884                       White or of European descent        Yes
# 77885                                        South Asian        Yes
# 77886                                                NaN        Yes
# 77887                       White or of European descent         No
# 77888                       White or of European descent        Yes
# 77889                       White or of European descent        NaN
# 77890                          Hispanic or Latino/Latina         No
# 77891                        Black or of African descent         No
# 77892                                                NaN         No
# 77893                       White or of European descent         No
# 77894                       White or of European descent         No
# 77895                                                NaN         No
# 77896                       White or of European descent         No
# 77897                                                NaN        NaN
# 77898                       White or of European descent        Yes
# 77899              White or of European descent;Biracial         No
# 77900                       White or of European descent        Yes
# 77901                                                NaN        Yes
# 77902                       White or of European descent        Yes
# 77903                                                NaN        Yes
# 77904                        Black or of African descent        NaN
# 77905  Hispanic or Latino/Latina;White or of European...         No
# 77906                                     Middle Eastern         No
# 77907                       White or of European descent         No
# 77908                                        South Asian        NaN
# 77909                       White or of European descent         No
# 77910                       White or of European descent        Yes
# 77911         Black or of African descent;Middle Eastern         No
# 77912                                                NaN         No
# 77913                       White or of European descent         No
# 77914                                                NaN        Yes
# 77915                       White or of European descent         No
# 77916                                                NaN         No
# 77917                                                NaN         No
# 77918  Hispanic or Latino/Latina;White or of European...         No
#
#                 SURVEYLENGTH                  SURVEYEASE
# 0      Appropriate in length  Neither easy nor difficult
# 1      Appropriate in length  Neither easy nor difficult
# 2      Appropriate in length  Neither easy nor difficult
# 3      Appropriate in length                        Easy
# 4      Appropriate in length                        Easy
# 5                   Too long  Neither easy nor difficult
# 6      Appropriate in length  Neither easy nor difficult
# 7      Appropriate in length  Neither easy nor difficult
# 8      Appropriate in length  Neither easy nor difficult
# 9      Appropriate in length                        Easy
# 10     Appropriate in length                        Easy
# 11                 Too short                        Easy
# 12                  Too long  Neither easy nor difficult
# 13     Appropriate in length  Neither easy nor difficult
# 14     Appropriate in length                        Easy
# 15     Appropriate in length  Neither easy nor difficult
# 16                  Too long                        Easy
# 17     Appropriate in length                        Easy
# 18     Appropriate in length                        Easy
# 19     Appropriate in length                        Easy
# 20     Appropriate in length                        Easy
# 21     Appropriate in length                        Easy
# 22                 Too short  Neither easy nor difficult
# 23     Appropriate in length                        Easy
# 24     Appropriate in length  Neither easy nor difficult
# 25                       NaN                         NaN
# 26     Appropriate in length                        Easy
# 27                  Too long                        Easy
# 28     Appropriate in length  Neither easy nor difficult
# 29     Appropriate in length  Neither easy nor difficult
# 30                 Too short  Neither easy nor difficult
# 31                  Too long  Neither easy nor difficult
# 32     Appropriate in length  Neither easy nor difficult
# 33     Appropriate in length  Neither easy nor difficult
# 34     Appropriate in length                        Easy
# 35     Appropriate in length                        Easy
# 36     Appropriate in length                        Easy
# 37                  Too long                        Easy
# 38     Appropriate in length                        Easy
# 39     Appropriate in length  Neither easy nor difficult
# 40                  Too long  Neither easy nor difficult
# 41     Appropriate in length                        Easy
# ...                      ...                         ...
# 77877  Appropriate in length                        Easy
# 77878              Too short                        Easy
# 77879               Too long                        Easy
# 77880  Appropriate in length                        Easy
# 77881               Too long                        Easy
# 77882               Too long  Neither easy nor difficult
# 77883  Appropriate in length                        Easy
# 77884               Too long                   Difficult
# 77885               Too long                        Easy
# 77886               Too long                        Easy
# 77887  Appropriate in length                        Easy
# 77888               Too long  Neither easy nor difficult
# 77889  Appropriate in length                        Easy
# 77890  Appropriate in length  Neither easy nor difficult
# 77891  Appropriate in length  Neither easy nor difficult
# 77892               Too long                   Difficult
# 77893  Appropriate in length                        Easy
# 77894  Appropriate in length  Neither easy nor difficult
# 77895  Appropriate in length                        Easy
# 77896  Appropriate in length                        Easy
# 77897                    NaN                         NaN
# 77898  Appropriate in length  Neither easy nor difficult
# 77899  Appropriate in length                        Easy
# 77900  Appropriate in length  Neither easy nor difficult
# 77901  Appropriate in length  Neither easy nor difficult
# 77902               Too long  Neither easy nor difficult
# 77903               Too long  Neither easy nor difficult
# 77904               Too long  Neither easy nor difficult
# 77905              Too short                        Easy
# 77906               Too long  Neither easy nor difficult
# 77907  Appropriate in length                   Difficult
# 77908  Appropriate in length                        Easy
# 77909  Appropriate in length                        Easy
# 77910  Appropriate in length                        Easy
# 77911  Appropriate in length  Neither easy nor difficult
# 77912                    NaN                         NaN
# 77913  Appropriate in length                        Easy
# 77914              Too short  Neither easy nor difficult
# 77915  Appropriate in length                        Easy
# 77916              Too short  Neither easy nor difficult
# 77917  Appropriate in length                        Easy
# 77918  Appropriate in length                        Easy
#
# [77919 rows x 84 columns]

# %%
pub_df = pd.read_csv('public.csv', index_col='RESPONDENT')

# %%
pub_df
# Out:
#             Unnamed: 0 HOBBYIST  \
# RESPONDENT
# 1                    0      Yes
# 2                    1       No
# 3                    2      Yes
# 4                    3       No
# 5                    4      Yes
# 6                    5      Yes
# 7                    6       No
# 8                    7      Yes
# 9                    8      Yes
# 11                  10      Yes
# 13                  12      Yes
# 14                  13      Yes
# 15                  14      Yes
# 16                  15      Yes
# 17                  16      Yes
# 18                  17      Yes
# 19                  18      Yes
# 20                  19       No
# 21                  20      Yes
# 22                  21      Yes
# 23                  22      Yes
# 24                  23      Yes
# 25                  24       No
# 26                  25      Yes
# 27                  26      Yes
# 28                  27      Yes
# 29                  28      Yes
# 30                  29       No
# 32                  31       No
# 33                  32       No
# 34                  33      Yes
# 36                  35      Yes
# 37                  36      Yes
# 38                  37      Yes
# 39                  38      Yes
# 40                  39      Yes
# 42                  41      Yes
# 43                  42      Yes
# 44                  43      Yes
# 45                  44      Yes
# 46                  45      Yes
# 47                  46      Yes
# ...                ...      ...
# 72325            88786      Yes
# 72492            88787      Yes
# 73695            88794      Yes
# 74976            88797      Yes
# 75496            88801      Yes
# 75842            88803      Yes
# 75974            88804      Yes
# 76444            88805       No
# 76822            88806       No
# 77920            88811      Yes
# 77968            88813       No
# 78292            88818       No
# 78326            88819      Yes
# 79354            88822       No
# 79616            88823       No
# 79795            88825      Yes
# 79798            88826      Yes
# 80116            88828       No
# 80319            88829      Yes
# 81934            88836      Yes
# 82134            88839      Yes
# 82717            88840       No
# 82789            88841      Yes
# 82805            88842      Yes
# 83000            88843       No
# 83786            88850       No
# 83862            88852      Yes
# 85396            88857       No
# 85738            88860      Yes
# 85955            88862      Yes
# 85961            88863      Yes
# 86012            88864      Yes
# 86566            88865      Yes
# 86638            88866      Yes
# 86806            88867      Yes
# 87352            88870      Yes
# 87386            88871      Yes
# 88182            88875      Yes
# 88212            88876       No
# 88282            88877      Yes
# 88377            88878      Yes
# 88863            88882      Yes
#
#                                                   OPENSOURCER  \
# RESPONDENT
# 1                                                       Never
# 2                                     Less than once per year
# 3                                                       Never
# 4                                                       Never
# 5                                  Once a month or more often
# 6                                                       Never
# 7                                                       Never
# 8                                     Less than once per year
# 9                                  Once a month or more often
# 11                                 Once a month or more often
# 13          Less than once a month but more than once per ...
# 14                                    Less than once per year
# 15                                                      Never
# 16                                                      Never
# 17          Less than once a month but more than once per ...
# 18          Less than once a month but more than once per ...
# 19                                                      Never
# 20                                                      Never
# 21                                 Once a month or more often
# 22                                    Less than once per year
# 23                                    Less than once per year
# 24                                                      Never
# 25                                                      Never
# 26                                    Less than once per year
# 27                                    Less than once per year
# 28                                    Less than once per year
# 29          Less than once a month but more than once per ...
# 30          Less than once a month but more than once per ...
# 32                                                      Never
# 33          Less than once a month but more than once per ...
# 34                                                      Never
# 36          Less than once a month but more than once per ...
# 37                                    Less than once per year
# 38                                                      Never
# 39                                    Less than once per year
# 40                                                      Never
# 42          Less than once a month but more than once per ...
# 43                                    Less than once per year
# 44                                 Once a month or more often
# 45                                                      Never
# 46                                    Less than once per year
# 47                                    Less than once per year
# ...                                                       ...
# 72325                              Once a month or more often
# 72492                              Once a month or more often
# 73695                                 Less than once per year
# 74976       Less than once a month but more than once per ...
# 75496                                 Less than once per year
# 75842                                 Less than once per year
# 75974                              Once a month or more often
# 76444                              Once a month or more often
# 76822       Less than once a month but more than once per ...
# 77920       Less than once a month but more than once per ...
# 77968                                 Less than once per year
# 78292                              Once a month or more often
# 78326                              Once a month or more often
# 79354                                 Less than once per year
# 79616                              Once a month or more often
# 79795       Less than once a month but more than once per ...
# 79798       Less than once a month but more than once per ...
# 80116                                 Less than once per year
# 80319                                                   Never
# 81934       Less than once a month but more than once per ...
# 82134                                                   Never
# 82717                                 Less than once per year
# 82789                              Once a month or more often
# 82805       Less than once a month but more than once per ...
# 83000                                 Less than once per year
# 83786                              Once a month or more often
# 83862                              Once a month or more often
# 85396       Less than once a month but more than once per ...
# 85738                                                   Never
# 85955                                 Less than once per year
# 85961                                 Less than once per year
# 86012                              Once a month or more often
# 86566       Less than once a month but more than once per ...
# 86638                                                   Never
# 86806                              Once a month or more often
# 87352                                 Less than once per year
# 87386       Less than once a month but more than once per ...
# 88182                              Once a month or more often
# 88212                                 Less than once per year
# 88282                              Once a month or more often
# 88377       Less than once a month but more than once per ...
# 88863                                 Less than once per year
#
#                                                    OPENSOURCE  \
# RESPONDENT
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# 6           The quality of OSS and closed source software ...
# 7           The quality of OSS and closed source software ...
# 8           OSS is, on average, of HIGHER quality than pro...
# 9           The quality of OSS and closed source software ...
# 11          The quality of OSS and closed source software ...
# 13          OSS is, on average, of HIGHER quality than pro...
# 14          The quality of OSS and closed source software ...
# 15          OSS is, on average, of HIGHER quality than pro...
# 16          The quality of OSS and closed source software ...
# 17          The quality of OSS and closed source software ...
# 18          The quality of OSS and closed source software ...
# 19          The quality of OSS and closed source software ...
# 20          OSS is, on average, of HIGHER quality than pro...
# 21          OSS is, on average, of HIGHER quality than pro...
# 22          OSS is, on average, of HIGHER quality than pro...
# 23          The quality of OSS and closed source software ...
# 24          OSS is, on average, of HIGHER quality than pro...
# 25          OSS is, on average, of HIGHER quality than pro...
# 26          The quality of OSS and closed source software ...
# 27          OSS is, on average, of HIGHER quality than pro...
# 28          The quality of OSS and closed source software ...
# 29          OSS is, on average, of HIGHER quality than pro...
# 30          OSS is, on average, of HIGHER quality than pro...
# 32          The quality of OSS and closed source software ...
# 33          OSS is, on average, of HIGHER quality than pro...
# 34          OSS is, on average, of HIGHER quality than pro...
# 36          The quality of OSS and closed source software ...
# 37          OSS is, on average, of LOWER quality than prop...
# 38          OSS is, on average, of LOWER quality than prop...
# 39          The quality of OSS and closed source software ...
# 40          OSS is, on average, of HIGHER quality than pro...
# 42          OSS is, on average, of HIGHER quality than pro...
# 43          OSS is, on average, of HIGHER quality than pro...
# 44          The quality of OSS and closed source software ...
# 45          The quality of OSS and closed source software ...
# 46          OSS is, on average, of HIGHER quality than pro...
# 47          OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 72325       OSS is, on average, of HIGHER quality than pro...
# 72492       The quality of OSS and closed source software ...
# 73695       OSS is, on average, of HIGHER quality than pro...
# 74976       The quality of OSS and closed source software ...
# 75496       The quality of OSS and closed source software ...
# 75842       OSS is, on average, of LOWER quality than prop...
# 75974       OSS is, on average, of HIGHER quality than pro...
# 76444       OSS is, on average, of LOWER quality than prop...
# 76822       OSS is, on average, of HIGHER quality than pro...
# 77920                                                     NaN
# 77968       The quality of OSS and closed source software ...
# 78292       OSS is, on average, of HIGHER quality than pro...
# 78326                                                     NaN
# 79354       The quality of OSS and closed source software ...
# 79616       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 79798       OSS is, on average, of HIGHER quality than pro...
# 80116                                                     NaN
# 80319       OSS is, on average, of HIGHER quality than pro...
# 81934       OSS is, on average, of HIGHER quality than pro...
# 82134                                                     NaN
# 82717       The quality of OSS and closed source software ...
# 82789       The quality of OSS and closed source software ...
# 82805       The quality of OSS and closed source software ...
# 83000       OSS is, on average, of HIGHER quality than pro...
# 83786       The quality of OSS and closed source software ...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 85396       OSS is, on average, of HIGHER quality than pro...
# 85738       The quality of OSS and closed source software ...
# 85955       OSS is, on average, of LOWER quality than prop...
# 85961       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
# 86566       OSS is, on average, of HIGHER quality than pro...
# 86638       OSS is, on average, of HIGHER quality than pro...
# 86806       OSS is, on average, of HIGHER quality than pro...
# 87352                                                     NaN
# 87386       OSS is, on average, of LOWER quality than prop...
# 88182       OSS is, on average, of HIGHER quality than pro...
# 88212       OSS is, on average, of HIGHER quality than pro...
# 88282       The quality of OSS and closed source software ...
# 88377       The quality of OSS and closed source software ...
# 88863       OSS is, on average, of HIGHER quality than pro...
#
#                                                    EMPLOYMENT         STUDENT  \
# RESPONDENT
# 1                      Not employed, and not looking for work              No
# 2                          Not employed, but looking for work  Yes, full-time
# 3                                          Employed full-time              No
# 4                                          Employed full-time              No
# 5                                          Employed full-time              No
# 6                                          Employed full-time              No
# 7           Independent contractor, freelancer, or self-em...              No
# 8                          Not employed, but looking for work             NaN
# 9                                          Employed full-time              No
# 11                                                        NaN  Yes, full-time
# 13                                         Employed full-time              No
# 14                                         Employed full-time              No
# 15                         Not employed, but looking for work  Yes, full-time
# 16                                         Employed full-time              No
# 17                                         Employed full-time              No
# 18                                         Employed full-time              No
# 19                                         Employed full-time              No
# 20                                         Employed full-time              No
# 21                                                        NaN             NaN
# 22                                         Employed full-time              No
# 23                                         Employed full-time              No
# 24                                         Employed full-time              No
# 25                                         Employed full-time              No
# 26                                         Employed full-time              No
# 27                         Not employed, but looking for work  Yes, part-time
# 28                                         Employed full-time              No
# 29                                         Employed full-time              No
# 30                                         Employed full-time              No
# 32                                         Employed full-time              No
# 33                                         Employed full-time  Yes, full-time
# 34                         Not employed, but looking for work              No
# 36                                         Employed full-time  Yes, full-time
# 37                                         Employed part-time  Yes, full-time
# 38                                         Employed full-time              No
# 39                                         Employed full-time              No
# 40          Independent contractor, freelancer, or self-em...  Yes, full-time
# 42                                         Employed full-time              No
# 43                                         Employed full-time              No
# 44                                         Employed full-time              No
# 45                                         Employed full-time              No
# 46          Independent contractor, freelancer, or self-em...              No
# 47                                         Employed full-time              No
# ...                                                       ...             ...
# 72325       Independent contractor, freelancer, or self-em...              No
# 72492                      Not employed, but looking for work              No
# 73695                                      Employed full-time              No
# 74976                      Not employed, but looking for work              No
# 75496                                      Employed full-time              No
# 75842                                      Employed full-time  Yes, full-time
# 75974                                      Employed full-time              No
# 76444                                      Employed full-time  Yes, full-time
# 76822                                                     NaN             NaN
# 77920                                      Employed full-time              No
# 77968       Independent contractor, freelancer, or self-em...              No
# 78292       Independent contractor, freelancer, or self-em...              No
# 78326                                                     NaN              No
# 79354                      Not employed, but looking for work              No
# 79616                      Not employed, but looking for work              No
# 79795                                      Employed full-time              No
# 79798                                      Employed part-time  Yes, full-time
# 80116                                      Employed part-time              No
# 80319       Independent contractor, freelancer, or self-em...              No
# 81934                  Not employed, and not looking for work              No
# 82134                                                     NaN              No
# 82717                      Not employed, but looking for work              No
# 82789                                                     NaN              No
# 82805       Independent contractor, freelancer, or self-em...              No
# 83000                                      Employed full-time              No
# 83786                                      Employed full-time              No
# 83862                                      Employed full-time  Yes, full-time
# 85396       Independent contractor, freelancer, or self-em...              No
# 85738                  Not employed, and not looking for work  Yes, full-time
# 85955                  Not employed, and not looking for work  Yes, part-time
# 85961                                                     NaN              No
# 86012                                      Employed full-time              No
# 86566                                                 Retired              No
# 86638                  Not employed, and not looking for work              No
# 86806                                      Employed part-time  Yes, part-time
# 87352                  Not employed, and not looking for work              No
# 87386       Independent contractor, freelancer, or self-em...  Yes, full-time
# 88182                                      Employed part-time             NaN
# 88212                                      Employed full-time              No
# 88282                      Not employed, but looking for work              No
# 88377                  Not employed, and not looking for work              No
# 88863                  Not employed, and not looking for work  Yes, full-time
#
#                                                       EDLEVEL  \
# RESPONDENT
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 11                                  Primary/elementary school
# 13                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 14                  Other doctoral degree (Ph.D, Ed.D., etc.)
# 15          Secondary school (e.g. American high school, G...
# 16                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 17                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 18                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 19          Some college/university study without earning ...
# 20                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 21                                                        NaN
# 22          Some college/university study without earning ...
# 23                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 24                                  Primary/elementary school
# 25                                           Associate degree
# 26          Some college/university study without earning ...
# 27          Some college/university study without earning ...
# 28                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 29                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 30                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 32                                           Associate degree
# 33                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 34                                  Primary/elementary school
# 36          Secondary school (e.g. American high school, G...
# 37                                           Associate degree
# 38                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 39                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 40          Secondary school (e.g. American high school, G...
# 42          Secondary school (e.g. American high school, G...
# 43                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 44                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 45                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 46                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 47                  Other doctoral degree (Ph.D, Ed.D., etc.)
# ...                                                       ...
# 72325       Secondary school (e.g. American high school, G...
# 72492       Some college/university study without earning ...
# 73695                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 74976                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75496             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 75842                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75974                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76444                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 76822                      Professional degree (JD, MD, etc.)
# 77920                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77968             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 78292               Other doctoral degree (Ph.D, Ed.D., etc.)
# 78326       Some college/university study without earning ...
# 79354                                        Associate degree
# 79616                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79795                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79798                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 80116       Some college/university study without earning ...
# 80319       Secondary school (e.g. American high school, G...
# 81934             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 82134                  I never completed any formal education
# 82717       Secondary school (e.g. American high school, G...
# 82789       Secondary school (e.g. American high school, G...
# 82805       Some college/university study without earning ...
# 83000       Secondary school (e.g. American high school, G...
# 83786               Other doctoral degree (Ph.D, Ed.D., etc.)
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 85396                      Professional degree (JD, MD, etc.)
# 85738       Secondary school (e.g. American high school, G...
# 85955       Secondary school (e.g. American high school, G...
# 85961               Other doctoral degree (Ph.D, Ed.D., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 86566       Some college/university study without earning ...
# 86638       Some college/university study without earning ...
# 86806       Secondary school (e.g. American high school, G...
# 87352                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87386                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88182       Secondary school (e.g. American high school, G...
# 88212       Secondary school (e.g. American high school, G...
# 88282       Some college/university study without earning ...
# 88377                               Primary/elementary school
# 88863                      Professional degree (JD, MD, etc.)
#
#                                                UNDERGRADMAJOR  \
# RESPONDENT
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 6                                   Mathematics or statistics
# 7           Another engineering discipline (ex. civil, ele...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 11                                                        NaN
# 13          Computer science, computer engineering, or sof...
# 14          Computer science, computer engineering, or sof...
# 15                                                        NaN
# 16                                                        NaN
# 17          Computer science, computer engineering, or sof...
# 18          Computer science, computer engineering, or sof...
# 19          Computer science, computer engineering, or sof...
# 20          Information systems, information technology, o...
# 21                                                        NaN
# 22                                                        NaN
# 23          Information systems, information technology, o...
# 24                                                        NaN
# 25          Computer science, computer engineering, or sof...
# 26          Computer science, computer engineering, or sof...
# 27          Information systems, information technology, o...
# 28          A business discipline (ex. accounting, finance...
# 29                                                        NaN
# 30          Computer science, computer engineering, or sof...
# 32          Information systems, information technology, o...
# 33          A natural science (ex. biology, chemistry, phy...
# 34                                                        NaN
# 36                                                        NaN
# 37          A social science (ex. anthropology, psychology...
# 38          Computer science, computer engineering, or sof...
# 39          Computer science, computer engineering, or sof...
# 40                                                        NaN
# 42                                                        NaN
# 43          Computer science, computer engineering, or sof...
# 44          Information systems, information technology, o...
# 45          Another engineering discipline (ex. civil, ele...
# 46          Another engineering discipline (ex. civil, ele...
# 47          A humanities discipline (ex. literature, histo...
# ...                                                       ...
# 72325                                                     NaN
# 72492                                I never declared a major
# 73695       Another engineering discipline (ex. civil, ele...
# 74976                               Mathematics or statistics
# 75496       Computer science, computer engineering, or sof...
# 75842       Computer science, computer engineering, or sof...
# 75974       Another engineering discipline (ex. civil, ele...
# 76444                                I never declared a major
# 76822       A health science (ex. nursing, pharmacy, radio...
# 77920       Computer science, computer engineering, or sof...
# 77968       Information systems, information technology, o...
# 78292       A health science (ex. nursing, pharmacy, radio...
# 78326       Computer science, computer engineering, or sof...
# 79354                                I never declared a major
# 79616                               Mathematics or statistics
# 79795       Computer science, computer engineering, or sof...
# 79798       Computer science, computer engineering, or sof...
# 80116                                                     NaN
# 80319                                                     NaN
# 81934       Computer science, computer engineering, or sof...
# 82134                                                     NaN
# 82717                                                     NaN
# 82789                                                     NaN
# 82805                                I never declared a major
# 83000                                                     NaN
# 83786       Computer science, computer engineering, or sof...
# 83862                                                     NaN
# 85396                                                     NaN
# 85738                                                     NaN
# 85955                                                     NaN
# 85961       Computer science, computer engineering, or sof...
# 86012       Another engineering discipline (ex. civil, ele...
# 86566       A humanities discipline (ex. literature, histo...
# 86638       Computer science, computer engineering, or sof...
# 86806                                                     NaN
# 87352       Computer science, computer engineering, or sof...
# 87386       Computer science, computer engineering, or sof...
# 88182                                                     NaN
# 88212                                                     NaN
# 88282       Computer science, computer engineering, or sof...
# 88377                                                     NaN
# 88863       Computer science, computer engineering, or sof...
#
#                                                      EDUOTHER  \
# RESPONDENT
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# 6           Taken an online course in programming or softw...
# 7           Taught yourself a new language, framework, or ...
# 8           Taught yourself a new language, framework, or ...
# 9           Taken an online course in programming or softw...
# 11                        Contributed to open source software
# 13          Taken an online course in programming or softw...
# 14          Completed an industry certification program (e...
# 15          Taken an online course in programming or softw...
# 16          Taken an online course in programming or softw...
# 17          Taken an online course in programming or softw...
# 18          Taken an online course in programming or softw...
# 19          Received on-the-job training in software devel...
# 20          Taken an online course in programming or softw...
# 21          Taught yourself a new language, framework, or ...
# 22          Taken an online course in programming or softw...
# 23          Taken an online course in programming or softw...
# 24          Taken an online course in programming or softw...
# 25          Taken an online course in programming or softw...
# 26          Taught yourself a new language, framework, or ...
# 27          Taken an online course in programming or softw...
# 28          Taken an online course in programming or softw...
# 29          Taken an online course in programming or softw...
# 30          Taught yourself a new language, framework, or ...
# 32          Completed an industry certification program (e...
# 33          Taken an online course in programming or softw...
# 34          Taken an online course in programming or softw...
# 36          Taken an online course in programming or softw...
# 37          Taken a part-time in-person course in programm...
# 38          Participated in a full-time developer training...
# 39          Taken an online course in programming or softw...
# 40          Taken an online course in programming or softw...
# 42          Taken a part-time in-person course in programm...
# 43          Taken an online course in programming or softw...
# 44          Taken an online course in programming or softw...
# 45          Received on-the-job training in software devel...
# 46          Taken an online course in programming or softw...
# 47          Taken an online course in programming or softw...
# ...                                                       ...
# 72325       Taken an online course in programming or softw...
# 72492       Taught yourself a new language, framework, or ...
# 73695       Taken an online course in programming or softw...
# 74976       Taken an online course in programming or softw...
# 75496       Taken an online course in programming or softw...
# 75842       Taken an online course in programming or softw...
# 75974       Taught yourself a new language, framework, or ...
# 76444       Participated in online coding competitions (e....
# 76822                                                     NaN
# 77920       Taken an online course in programming or softw...
# 77968       Taken a part-time in-person course in programm...
# 78292       Completed an industry certification program (e...
# 78326       Taken an online course in programming or softw...
# 79354       Taken an online course in programming or softw...
# 79616       Taken an online course in programming or softw...
# 79795       Taken an online course in programming or softw...
# 79798       Taught yourself a new language, framework, or ...
# 80116       Taught yourself a new language, framework, or ...
# 80319       Taught yourself a new language, framework, or ...
# 81934       Taken an online course in programming or softw...
# 82134                                                     NaN
# 82717                                                     NaN
# 82789       Taken an online course in programming or softw...
# 82805       Taken an online course in programming or softw...
# 83000       Taken an online course in programming or softw...
# 83786       Taught yourself a new language, framework, or ...
# 83862                             Participated in a hackathon
# 85396       Taken an online course in programming or softw...
# 85738       Taught yourself a new language, framework, or ...
# 85955       Taught yourself a new language, framework, or ...
# 85961       Taught yourself a new language, framework, or ...
# 86012       Taught yourself a new language, framework, or ...
# 86566       Taken a part-time in-person course in programm...
# 86638                                                     NaN
# 86806                     Contributed to open source software
# 87352                                                     NaN
# 87386       Taken an online course in programming or softw...
# 88182       Taken an online course in programming or softw...
# 88212       Taught yourself a new language, framework, or ...
# 88282       Taught yourself a new language, framework, or ...
# 88377       Taught yourself a new language, framework, or ...
# 88863       Taken an online course in programming or softw...
#
#                                                       ORGSIZE  \
# RESPONDENT
# 1                                                         NaN
# 2                                                         NaN
# 3                                        100 to 499 employees
# 4                                        100 to 499 employees
# 5                                    10,000 or more employees
# 6                                                         NaN
# 7           Just me - I am a freelancer, sole proprietor, ...
# 8                                                         NaN
# 9                                          10 to 19 employees
# 11                                                        NaN
# 13                                         10 to 19 employees
# 14                                       100 to 499 employees
# 15                                                        NaN
# 16                                       100 to 499 employees
# 17                                         20 to 99 employees
# 18                                   1,000 to 4,999 employees
# 19                                       100 to 499 employees
# 20                                   1,000 to 4,999 employees
# 21                                                        NaN
# 22                                   10,000 or more employees
# 23                                   10,000 or more employees
# 24                                         10 to 19 employees
# 25                                              2-9 employees
# 26                                   10,000 or more employees
# 27                                                        NaN
# 28                                              2-9 employees
# 29                                   10,000 or more employees
# 30                                   1,000 to 4,999 employees
# 32                                       100 to 499 employees
# 33                                   10,000 or more employees
# 34                                                        NaN
# 36                                   1,000 to 4,999 employees
# 37                                       100 to 499 employees
# 38                                         10 to 19 employees
# 39                                       100 to 499 employees
# 40                                                        NaN
# 42          Just me - I am a freelancer, sole proprietor, ...
# 43                                   10,000 or more employees
# 44                                   10,000 or more employees
# 45                                   1,000 to 4,999 employees
# 46          Just me - I am a freelancer, sole proprietor, ...
# 47                                       100 to 499 employees
# ...                                                       ...
# 72325       Just me - I am a freelancer, sole proprietor, ...
# 72492                                                     NaN
# 73695                                    500 to 999 employees
# 74976                                                     NaN
# 75496                                10,000 or more employees
# 75842                                      20 to 99 employees
# 75974                                1,000 to 4,999 employees
# 76444                                                     NaN
# 76822                                                     NaN
# 77920                                1,000 to 4,999 employees
# 77968                                           2-9 employees
# 78292       Just me - I am a freelancer, sole proprietor, ...
# 78326                                                     NaN
# 79354                                                     NaN
# 79616                                                     NaN
# 79795                                    500 to 999 employees
# 79798                                      10 to 19 employees
# 80116                                                     NaN
# 80319       Just me - I am a freelancer, sole proprietor, ...
# 81934                                                     NaN
# 82134                                                     NaN
# 82717                                                     NaN
# 82789                                                     NaN
# 82805       Just me - I am a freelancer, sole proprietor, ...
# 83000                                    100 to 499 employees
# 83786                                    500 to 999 employees
# 83862                                                     NaN
# 85396                                    100 to 499 employees
# 85738                                                     NaN
# 85955                                                     NaN
# 85961                                                     NaN
# 86012                                    100 to 499 employees
# 86566                                                     NaN
# 86638                                                     NaN
# 86806       Just me - I am a freelancer, sole proprietor, ...
# 87352                                                     NaN
# 87386                                                     NaN
# 88182                                      10 to 19 employees
# 88212                                      10 to 19 employees
# 88282                                                     NaN
# 88377                                                     NaN
# 88863                                                     NaN
#
#                                                       DEVTYPE  \
# RESPONDENT
# 1                                                         NaN
# 2           Developer, desktop or enterprise applications;...
# 3           Designer;Developer, back-end;Developer, front-...
# 4                                       Developer, full-stack
# 5           Academic researcher;Developer, desktop or ente...
# 6           Data or business analyst;Data scientist or mac...
# 7                               Designer;Developer, front-end
# 8              Developer, back-end;Engineer, site reliability
# 9           Database administrator;Developer, back-end;Dev...
# 11                                                        NaN
# 13          Data or business analyst;Database administrato...
# 14              Developer, desktop or enterprise applications
# 15                                                    Student
# 16                                      Developer, full-stack
# 17          Developer, back-end;Developer, front-end;Devel...
# 18                                   Data or business analyst
# 19                                      Developer, full-stack
# 20          Database administrator;Designer;Developer, bac...
# 21                                                        NaN
# 22          Data or business analyst;Designer;Developer, b...
# 23                                      Developer, full-stack
# 24                                       Developer, front-end
# 25          Designer;Developer, back-end;Developer, front-...
# 26          Designer;Developer, back-end;Developer, deskto...
# 27          Developer, back-end;Developer, front-end;Devel...
# 28          Designer;Developer, front-end;Developer, full-...
# 29                              Developer, front-end;Educator
# 30               DevOps specialist;Engineer, site reliability
# 32                                      Developer, full-stack
# 33          Academic researcher;Data scientist or machine ...
# 34                                      Developer, full-stack
# 36                                  Developer, mobile;Student
# 37                                                    Student
# 38                       Developer, full-stack;Engineer, data
# 39          Database administrator;Developer, back-end;Dev...
# 40          Developer, back-end;Developer, full-stack;Student
# 42          Academic researcher;Data or business analyst;D...
# 43          Developer, front-end;Developer, game or graphi...
# 44          Developer, back-end;Developer, desktop or ente...
# 45                                        Engineering manager
# 46                       Developer, full-stack;Engineer, data
# 47                                        Engineering manager
# ...                                                       ...
# 72325       Academic researcher;Data scientist or machine ...
# 72492       Developer, back-end;Developer, desktop or ente...
# 73695                                Data or business analyst
# 74976                                                     NaN
# 75496                                       DevOps specialist
# 75842                                   Developer, full-stack
# 75974       Developer, full-stack;DevOps specialist;Engine...
# 76444       Developer, back-end;Developer, desktop or ente...
# 76822                                                     NaN
# 77920                                   Developer, full-stack
# 77968       Data or business analyst;Data scientist or mac...
# 78292                                     Academic researcher
# 78326                                                     NaN
# 79354           Developer, back-end;Developer, mobile;Student
# 79616         Marketing or sales professional;Product manager
# 79795                                   Developer, QA or test
# ...
# 36            No                          Straight / Heterosexual
# 37            No                                              NaN
# 38            No                                              NaN
# 39            No                                         Bisexual
# 40            No                          Bisexual;Gay or Lesbian
# 42            No                          Straight / Heterosexual
# 43            No                          Straight / Heterosexual
# 44            No                          Straight / Heterosexual
# 45            No                          Straight / Heterosexual
# 46            No                          Straight / Heterosexual
# 47            No                          Straight / Heterosexual
# ...          ...                                              ...
# 72325         No                                              NaN
# 72492         No                          Bisexual;Gay or Lesbian
# 73695         No                          Straight / Heterosexual
# 74976         No                                   Gay or Lesbian
# 75496         No                          Straight / Heterosexual
# 75842         No                                              NaN
# 75974         No                                              NaN
# 76444         No                                              NaN
# 76822         No                          Straight / Heterosexual
# 77920         No                          Straight / Heterosexual
# 77968         No                          Straight / Heterosexual
# 78292         No                          Straight / Heterosexual
# 78326         No                 Bisexual;Straight / Heterosexual
# 79354         No                          Straight / Heterosexual
# 79616         No                                              NaN
# 79795         No                          Straight / Heterosexual
# 79798         No                          Straight / Heterosexual
# 80116         No                          Straight / Heterosexual
# 80319         No                          Straight / Heterosexual
# 81934         No                          Straight / Heterosexual
# 82134         No                                              NaN
# 82717         No                          Straight / Heterosexual
# 82789         No                          Straight / Heterosexual
# 82805         No                          Straight / Heterosexual
# 83000         No                          Straight / Heterosexual
# 83786         No                                              NaN
# 83862         No                          Straight / Heterosexual
# 85396         No                          Straight / Heterosexual
# 85738         No                          Straight / Heterosexual
# 85955         No                                              NaN
# 85961         No                                   Gay or Lesbian
# 86012         No                                              NaN
# 86566         No                                              NaN
# 86638         No                          Straight / Heterosexual
# 86806         No                                              NaN
# 87352         No                                              NaN
# 87386         No                          Straight / Heterosexual
# 88182         No                          Straight / Heterosexual
# 88212         No                          Straight / Heterosexual
# 88282         No                          Straight / Heterosexual
# 88377         No                                              NaN
# 88863         No                          Straight / Heterosexual
#
#                                                     ETHNICITY DEPENDENTS  \
# RESPONDENT
# 1                                                         NaN         No
# 2                                                         NaN         No
# 3                                                         NaN        Yes
# 4                                White or of European descent         No
# 5                    White or of European descent;Multiracial         No
# 6                                                  East Asian         No
# 7                                White or of European descent        Yes
# 8                                                         NaN        NaN
# 9                                White or of European descent         No
# 11          Black or of African descent;East Asian;Hispani...         No
# 13                               White or of European descent        Yes
# 14                               White or of European descent         No
# 15                                                        NaN        Yes
# 16                               White or of European descent         No
# 17                      Hispanic or Latino/Latina;Multiracial         No
# 18                               White or of European descent        Yes
# 19                                  Hispanic or Latino/Latina        Yes
# 20                               White or of European descent        Yes
# 21                                                        NaN         No
# 22                               White or of European descent        Yes
# 23                                Black or of African descent         No
# 24                                             Middle Eastern         No
# 25                               White or of European descent         No
# 26                                                        NaN         No
# 27                                  Hispanic or Latino/Latina         No
# 28                                                        NaN        NaN
# 29                               White or of European descent        Yes
# 30                               White or of European descent         No
# 32                               White or of European descent         No
# 33                                  Hispanic or Latino/Latina         No
# 34                                                South Asian        Yes
# 36                               White or of European descent         No
# 37                               White or of European descent         No
# 38                                                        NaN        Yes
# 39                               White or of European descent         No
# 40                               White or of European descent         No
# 42                                             Middle Eastern        NaN
# 43                                  Hispanic or Latino/Latina         No
# 44                               White or of European descent        Yes
# 45                               White or of European descent         No
# 46                               White or of European descent         No
# 47                               White or of European descent        Yes
# ...                                                       ...        ...
# 72325                            White or of European descent         No
# 72492                               Hispanic or Latino/Latina         No
# 73695                                                     NaN         No
# 74976                            White or of European descent         No
# 75496                                             South Asian        NaN
# 75842                                                     NaN        NaN
# 75974                                          Middle Eastern        Yes
# 76444                            White or of European descent        Yes
# 76822                                             South Asian        Yes
# 77920                                                     NaN        Yes
# 77968                            White or of European descent         No
# 78292                            White or of European descent        Yes
# 78326                            White or of European descent        NaN
# 79354                               Hispanic or Latino/Latina         No
# 79616                             Black or of African descent         No
# 79795                                                     NaN         No
# 79798                            White or of European descent         No
# 80116                            White or of European descent         No
# 80319                                                     NaN         No
# 81934                            White or of European descent         No
# 82134                                                     NaN        NaN
# 82717                            White or of European descent        Yes
# 82789                   White or of European descent;Biracial         No
# 82805                            White or of European descent        Yes
# 83000                                                     NaN        Yes
# 83786                            White or of European descent        Yes
# 83862                                                     NaN        Yes
# 85396                             Black or of African descent        NaN
# 85738       Hispanic or Latino/Latina;White or of European...         No
# 85955                                          Middle Eastern         No
# 85961                            White or of European descent         No
# 86012                                             South Asian        NaN
# 86566                            White or of European descent         No
# 86638                            White or of European descent        Yes
# 86806              Black or of African descent;Middle Eastern         No
# 87352                                                     NaN         No
# 87386                            White or of European descent         No
# 88182                                                     NaN        Yes
# 88212                            White or of European descent         No
# 88282                                                     NaN         No
# 88377                                                     NaN         No
# 88863       Hispanic or Latino/Latina;White or of European...         No
#
#                      SURVEYLENGTH                  SURVEYEASE
# RESPONDENT
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# 7           Appropriate in length  Neither easy nor difficult
# 8           Appropriate in length  Neither easy nor difficult
# 9           Appropriate in length  Neither easy nor difficult
# 11          Appropriate in length                        Easy
# 13          Appropriate in length                        Easy
# 14                      Too short                        Easy
# 15                       Too long  Neither easy nor difficult
# 16          Appropriate in length  Neither easy nor difficult
# 17          Appropriate in length                        Easy
# 18          Appropriate in length  Neither easy nor difficult
# 19                       Too long                        Easy
# 20          Appropriate in length                        Easy
# 21          Appropriate in length                        Easy
# 22          Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 24          Appropriate in length                        Easy
# 25                      Too short  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 27          Appropriate in length  Neither easy nor difficult
# 28                            NaN                         NaN
# 29          Appropriate in length                        Easy
# 30                       Too long                        Easy
# 32          Appropriate in length  Neither easy nor difficult
# 33          Appropriate in length  Neither easy nor difficult
# 34                      Too short  Neither easy nor difficult
# 36                       Too long  Neither easy nor difficult
# 37          Appropriate in length  Neither easy nor difficult
# 38          Appropriate in length  Neither easy nor difficult
# 39          Appropriate in length                        Easy
# 40          Appropriate in length                        Easy
# 42          Appropriate in length                        Easy
# 43                       Too long                        Easy
# 44          Appropriate in length                        Easy
# 45          Appropriate in length  Neither easy nor difficult
# 46                       Too long  Neither easy nor difficult
# 47          Appropriate in length                        Easy
# ...                           ...                         ...
# 72325       Appropriate in length                        Easy
# 72492                   Too short                        Easy
# 73695                    Too long                        Easy
# 74976       Appropriate in length                        Easy
# 75496                    Too long                        Easy
# 75842                    Too long  Neither easy nor difficult
# 75974       Appropriate in length                        Easy
# 76444                    Too long                   Difficult
# 76822                    Too long                        Easy
# 77920                    Too long                        Easy
# 77968       Appropriate in length                        Easy
# 78292                    Too long  Neither easy nor difficult
# 78326       Appropriate in length                        Easy
# 79354       Appropriate in length  Neither easy nor difficult
# 79616       Appropriate in length  Neither easy nor difficult
# 79795                    Too long                   Difficult
# 79798       Appropriate in length                        Easy
# 80116       Appropriate in length  Neither easy nor difficult
# 80319       Appropriate in length                        Easy
# 81934       Appropriate in length                        Easy
# 82134                         NaN                         NaN
# 82717       Appropriate in length  Neither easy nor difficult
# 82789       Appropriate in length                        Easy
# 82805       Appropriate in length  Neither easy nor difficult
# 83000       Appropriate in length  Neither easy nor difficult
# 83786                    Too long  Neither easy nor difficult
# 83862                    Too long  Neither easy nor difficult
# 85396                    Too long  Neither easy nor difficult
# 85738                   Too short                        Easy
# 85955                    Too long  Neither easy nor difficult
# 85961       Appropriate in length                   Difficult
# 86012       Appropriate in length                        Easy
# 86566       Appropriate in length                        Easy
# 86638       Appropriate in length                        Easy
# 86806       Appropriate in length  Neither easy nor difficult
# 87352                         NaN                         NaN
# 87386       Appropriate in length                        Easy
# 88182                   Too short  Neither easy nor difficult
# 88212       Appropriate in length                        Easy
# 88282                   Too short  Neither easy nor difficult
# 88377       Appropriate in length                        Easy
# 88863       Appropriate in length                        Easy
#
# [77919 rows x 83 columns]

# %%
pub_df['STUDENT']
# Out:
# RESPONDENT
# 1                    No
# 2        Yes, full-time
# 3                    No
# 4                    No
# 5                    No
# 6                    No
# 7                    No
# 8                   NaN
# 9                    No
# 11       Yes, full-time
# 13                   No
# 14                   No
# 15       Yes, full-time
# 16                   No
# 17                   No
# 18                   No
# 19                   No
# 20                   No
# 21                  NaN
# 22                   No
# 23                   No
# 24                   No
# 25                   No
# 26                   No
# 27       Yes, part-time
# 28                   No
# 29                   No
# 30                   No
# 32                   No
# 33       Yes, full-time
# 34                   No
# 36       Yes, full-time
# 37       Yes, full-time
# 38                   No
# 39                   No
# 40       Yes, full-time
# 42                   No
# 43                   No
# 44                   No
# 45                   No
# 46                   No
# 47                   No
#               ...
# 72325                No
# 72492                No
# 73695                No
# 74976                No
# 75496                No
# 75842    Yes, full-time
# 75974                No
# 76444    Yes, full-time
# 76822               NaN
# 77920                No
# 77968                No
# 78292                No
# 78326                No
# 79354                No
# 79616                No
# 79795                No
# 79798    Yes, full-time
# 80116                No
# 80319                No
# 81934                No
# 82134                No
# 82717                No
# 82789                No
# 82805                No
# 83000                No
# 83786                No
# 83862    Yes, full-time
# 85396                No
# 85738    Yes, full-time
# 85955    Yes, part-time
# 85961                No
# 86012                No
# 86566                No
# 86638                No
# 86806    Yes, part-time
# 87352                No
# 87386    Yes, full-time
# 88182               NaN
# 88212                No
# 88282                No
# 88377                No
# 88863    Yes, full-time
# Name: STUDENT, Length: 77919, dtype: object

# %%
pub_df.iloc[1]
# Out:
# Unnamed: 0                                                                1
# HOBBYIST                                                                 No
# OPENSOURCER                                         Less than once per year
# OPENSOURCE                The quality of OSS and closed source software ...
# EMPLOYMENT                               Not employed, but looking for work
# STUDENT                                                      Yes, full-time
# EDLEVEL                   Secondary school (e.g. American high school, G...
# UNDERGRADMAJOR                                                          NaN
# EDUOTHER                  Taken an online course in programming or softw...
# ORGSIZE                                                                 NaN
# DEVTYPE                   Developer, desktop or enterprise applications;...
# YEARSCODE                                                               NaN
# AGE1STCODE                                                               17
# YEARSCODEPRO                                                            NaN
# CAREERSAT                                                               NaN
# JOBSAT                                                                  NaN
# MGRIDIOT                                                                NaN
# MGRMONEY                                                                NaN
# MGRWANT                                                                 NaN
# JOBSEEK                                     I am actively looking for a job
# LASTHIREDATE                                           I've never had a job
# LASTINT                                                                 NaN
# FIZZBUZZ                                                                NaN
# JOBFACTORS                Financial performance or funding status of the...
# RESUMEUPDATE              Something else changed (education, award, medi...
# CURRENCYSYMBOL                                                          NaN
# CURRENCYDESC                                                            NaN
# COMPTOTAL                                                               NaN
# COMPFREQ                                                                NaN
# CONVERTEDCOMP                                                           NaN
# WORKWEEKHRS                                                             NaN
# WORKPLAN                                                                NaN
# WORKCHALLENGE                                                           NaN
# WORKREMOTE                                                              NaN
# WORKLOC                                                                 NaN
# IMPSYN                                                                  NaN
# CODEREV                                                                 NaN
# CODEREVHRS                                                              NaN
# UNITTESTS                                                               NaN
# PURCHASEHOW                                                             NaN
# PURCHASEWHAT                                                            NaN
# LANGUAGEWORKEDWITH                                      C++;HTML/CSS;Python
# LANGUAGEDESIRENEXTYEAR                          C++;HTML/CSS;JavaScript;SQL
# DATABASEWORKEDWITH                                                      NaN
# DATABASEDESIRENEXTYEAR                                                MySQL
# PLATFORMWORKEDWITH                                                  Windows
# PLATFORMDESIRENEXTYEAR                                              Windows
# WEBFRAMEWORKEDWITH                                                   Django
# WEBFRAMEDESIRENEXTYEAR                                               Django
# MISCTECHWORKEDWITH                                                      NaN
# MISCTECHDESIRENEXTYEAR                                                  NaN
# DEVENVIRON                                                     Atom;PyCharm
# OPSYS                                                               Windows
# CONTAINERS                                          I do not use containers
# BLOCKCHAINORG                                                           NaN
# BLOCKCHAINIS              Useful across many domains and could change ma...
# BETTERLIFE                                                              Yes
# ITPERSON                                                                Yes
# OFFON                                                                   Yes
# SOCIALMEDIA                                                       Instagram
# EXTRAVERSION                                                         Online
# SCREENNAME                                                         Username
# SOVISIT1ST                                                             2017
# SOVISITFREQ                                           Daily or almost daily
# SOVISITTO                 Find answers to specific questions;Learn how t...
# SOFINDANSWER                                             3-5 times per week
# SOTIMESAVED                                  Stack Overflow was much faster
# SOHOWMUCHTIME                                                 11-30 minutes
# SOACCOUNT                                                               Yes
# SOPARTFREQ                                  A few times per month or weekly
# SOJOBS                    No, I knew that Stack Overflow had a job board...
# ENTTEAMS                                No, and I don't know what those are
# SOCOMM                                                        Yes, somewhat
# WELCOMECHANGE                       Just as welcome now as I felt last year
# SONEWCONTENT              Tech articles written by other developers;Indu...
# AGE                                                                      19
# GENDER                                                                  Man
# TRANS                                                                    No
# SEXUALITY                                           Straight / Heterosexual
# ETHNICITY                                                               NaN
# DEPENDENTS                                                               No
# SURVEYLENGTH                                          Appropriate in length
# SURVEYEASE                                       Neither easy nor difficult
# Name: 2, dtype: object

# %%
pub_df.iloc[[1],8]
# Out:
# RESPONDENT
# 2    Taken an online course in programming or softw...
# Name: EDUOTHER, dtype: object

# %%
filt= pub_df['MAInBranch'] == 'am'

filt= pub_df['STUDENT'] == 'no'

# %%
pub_df[filt]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, HOBBYIST, OPENSOURCER, OPENSOURCE, EMPLOYMENT, STUDENT, EDLEVEL, UNDERGRADMAJOR, EDUOTHER, ORGSIZE, DEVTYPE, YEARSCODE, AGE1STCODE, YEARSCODEPRO, CAREERSAT, JOBSAT, MGRIDIOT, MGRMONEY, MGRWANT, JOBSEEK, LASTHIREDATE, LASTINT, FIZZBUZZ, JOBFACTORS, RESUMEUPDATE, CURRENCYSYMBOL, CURRENCYDESC, COMPTOTAL, COMPFREQ, CONVERTEDCOMP, WORKWEEKHRS, WORKPLAN, WORKCHALLENGE, WORKREMOTE, WORKLOC, IMPSYN, CODEREV, CODEREVHRS, UNITTESTS, PURCHASEHOW, PURCHASEWHAT, LANGUAGEWORKEDWITH, LANGUAGEDESIRENEXTYEAR, DATABASEWORKEDWITH, DATABASEDESIRENEXTYEAR, PLATFORMWORKEDWITH, PLATFORMDESIRENEXTYEAR, WEBFRAMEWORKEDWITH, WEBFRAMEDESIRENEXTYEAR, MISCTECHWORKEDWITH, MISCTECHDESIRENEXTYEAR, DEVENVIRON, OPSYS, CONTAINERS, BLOCKCHAINORG, BLOCKCHAINIS, BETTERLIFE, ITPERSON, OFFON, SOCIALMEDIA, EXTRAVERSION, SCREENNAME, SOVISIT1ST, SOVISITFREQ, SOVISITTO, SOFINDANSWER, SOTIMESAVED, SOHOWMUCHTIME, SOACCOUNT, SOPARTFREQ, SOJOBS, ENTTEAMS, SOCOMM, WELCOMECHANGE, SONEWCONTENT, AGE, GENDER, TRANS, SEXUALITY, ETHNICITY, DEPENDENTS, SURVEYLENGTH, SURVEYEASE]
# Index: []

# %%
filt = (pub_df['Gender']== 'Man')

Man_df = pub_df.loc[filt]


Man_df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
Man_df.to_csv('public.csv')
