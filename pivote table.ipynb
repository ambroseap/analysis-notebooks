# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib as mpl

import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df = pd.read_csv('datasets.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Ticket','Name'],inplace=True,axis=1)

# %%
table = pd.pivot_table(data=df,index=['Sex'])
table
# Out:
#               Age       Fare     Parch    Pclass     SibSp  Survived
# Sex
# female  27.915709  44.479818  0.649682  2.159236  0.694268  0.742038
# male    30.726645  25.523893  0.235702  2.389948  0.429809  0.188908

# %%
table.plot(kind='bar');

# %%
table = pd.pivot_table(df,index=['Sex','Pclass'])
table
# Out:
#                      Age        Fare     Parch     SibSp  Survived
# Sex    Pclass
# female 1       34.611765  106.125798  0.457447  0.553191  0.968085
#        2       28.722973   21.970121  0.605263  0.486842  0.921053
#        3       21.750000   16.118810  0.798611  0.895833  0.500000
# male   1       41.281386   67.226127  0.278689  0.311475  0.368852
#        2       30.740707   19.741782  0.222222  0.342593  0.157407
#        3       26.507589   12.661633  0.224784  0.498559  0.135447

# %%
table.plot(kind='bar');

# %%
#different aggregate functions
table = pd.pivot_table(df,index=['Sex','Pclass'],aggfunc={'Age':np.mean,'Survived':np.sum})
table
# Out:
#                      Age  Survived
# Sex    Pclass
# female 1       34.611765        91
#        2       28.722973        70
#        3       21.750000        72
# male   1       41.281386        45
#        2       30.740707        17
#        3       26.507589        47

# %%
table = pd.pivot_table(df,index=['Sex','Pclass'],values=['Survived'], aggfunc=np.mean)
table
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
table.plot(kind='bar');

# %%
table = pd.pivot_table(df,index=['Sex'],columns=['Pclass'],values=['Survived'],aggfunc=np.sum)
table
# Out:
#        Survived
# Pclass        1   2   3
# Sex
# female       91  70  72
# male         45  17  47

# %%
table.plot(kind='bar');

# %%
#display null values
table = pd.pivot_table(df,index=['Sex','Survived','Pclass'],columns=['Embarked'],values=['Age'],aggfunc=np.mean)
table
# Out:
#                               Age
# Embarked                        C          Q          S
# Sex    Survived Pclass
# female 0        1       50.000000        NaN  13.500000
#                 2             NaN        NaN  36.000000
#                 3       20.700000  28.100000  23.688889
#        1        1       35.675676  33.000000  33.619048
#                 2       19.142857  30.000000  29.091667
#                 3       11.045455  17.600000  22.548387
# male   0        1       43.050000  44.000000  45.362500
#                 2       29.500000  57.000000  33.414474
#                 3       27.555556  28.076923  27.168478
#        1        1       36.437500        NaN  36.121667
#                 2        1.000000        NaN  17.095000
#                 3       18.488571  29.000000  22.933333

# %%
#handling null values
#I will be replacing the NaN values with the mean value from the ‘Age’ column:
table = pd.pivot_table(df,index=['Sex','Survived','Pclass'],columns=['Embarked'],values=['Age'],aggfunc=np.mean,fill_value=np.mean(df['Age']))
table
# Out:
#                               Age
# Embarked                        C          Q          S
# Sex    Survived Pclass
# female 0        1       50.000000  29.699118  13.500000
#                 2       29.699118  29.699118  36.000000
#                 3       20.700000  28.100000  23.688889
#        1        1       35.675676  33.000000  33.619048
#                 2       19.142857  30.000000  29.091667
#                 3       11.045455  17.600000  22.548387
# male   0        1       43.050000  44.000000  45.362500
#                 2       29.500000  57.000000  33.414474
#                 3       27.555556  28.076923  27.168478
#        1        1       36.437500  29.699118  36.121667
#                 2        1.000000  29.699118  17.095000
#                 3       18.488571  29.000000  22.933333

# %%
df.set_index('Sex')
# Out:
#         Survived  Pclass   Age  SibSp  Parch      Fare        Cabin Embarked
# Sex
# male           0       3  22.0      1      0    7.2500          NaN        S
# female         1       1  38.0      1      0   71.2833          C85        C
# female         1       3  26.0      0      0    7.9250          NaN        S
# female         1       1  35.0      1      0   53.1000         C123        S
# male           0       3  35.0      0      0    8.0500          NaN        S
# male           0       3   NaN      0      0    8.4583          NaN        Q
# male           0       1  54.0      0      0   51.8625          E46        S
# male           0       3   2.0      3      1   21.0750          NaN        S
# female         1       3  27.0      0      2   11.1333          NaN        S
# female         1       2  14.0      1      0   30.0708          NaN        C
# female         1       3   4.0      1      1   16.7000           G6        S
# female         1       1  58.0      0      0   26.5500         C103        S
# male           0       3  20.0      0      0    8.0500          NaN        S
# male           0       3  39.0      1      5   31.2750          NaN        S
# female         0       3  14.0      0      0    7.8542          NaN        S
# female         1       2  55.0      0      0   16.0000          NaN        S
# male           0       3   2.0      4      1   29.1250          NaN        Q
# male           1       2   NaN      0      0   13.0000          NaN        S
# female         0       3  31.0      1      0   18.0000          NaN        S
# female         1       3   NaN      0      0    7.2250          NaN        C
# male           0       2  35.0      0      0   26.0000          NaN        S
# male           1       2  34.0      0      0   13.0000          D56        S
# female         1       3  15.0      0      0    8.0292          NaN        Q
# male           1       1  28.0      0      0   35.5000           A6        S
# female         0       3   8.0      3      1   21.0750          NaN        S
# female         1       3  38.0      1      5   31.3875          NaN        S
# male           0       3   NaN      0      0    7.2250          NaN        C
# male           0       1  19.0      3      2  263.0000  C23 C25 C27        S
# female         1       3   NaN      0      0    7.8792          NaN        Q
# male           0       3   NaN      0      0    7.8958          NaN        S
# ...          ...     ...   ...    ...    ...       ...          ...      ...
# male           0       2  21.0      1      0   11.5000          NaN        S
# female         1       1  48.0      0      0   25.9292          D17        S
# female         0       3   NaN      8      2   69.5500          NaN        S
# male           0       2  24.0      0      0   13.0000          NaN        S
# female         1       2  42.0      0      0   13.0000          NaN        S
# female         1       2  27.0      1      0   13.8583          NaN        C
# male           0       1  31.0      0      0   50.4958          A24        S
# male           0       3   NaN      0      0    9.5000          NaN        S
# male           1       3   4.0      1      1   11.1333          NaN        S
# male           0       3  26.0      0      0    7.8958          NaN        S
# female         1       1  47.0      1      1   52.5542          D35        S
# male           0       1  33.0      0      0    5.0000  B51 B53 B55        S
# male           0       3  47.0      0      0    9.0000          NaN        S
# female         1       2  28.0      1      0   24.0000          NaN        C
# female         1       3  15.0      0      0    7.2250          NaN        C
# male           0       3  20.0      0      0    9.8458          NaN        S
# male           0       3  19.0      0      0    7.8958          NaN        S
# male           0       3   NaN      0      0    7.8958          NaN        S
# female         1       1  56.0      0      1   83.1583          C50        C
# female         1       2  25.0      0      1   26.0000          NaN        S
# male           0       3  33.0      0      0    7.8958          NaN        S
# female         0       3  22.0      0      0   10.5167          NaN        S
# male           0       2  28.0      0      0   10.5000          NaN        S
# male           0       3  25.0      0      0    7.0500          NaN        S
# female         0       3  39.0      0      5   29.1250          NaN        Q
# male           0       2  27.0      0      0   13.0000          NaN        S
# female         1       1  19.0      0      0   30.0000          B42        S
# female         0       3   NaN      1      2   23.4500          NaN        S
# male           1       1  26.0      0      0   30.0000         C148        C
# male           0       3  32.0      0      0    7.7500          NaN        Q
#
# [891 rows x 8 columns]

# %%
df.apply(lambda x: x.max())
# Out:
# Survived          1
# Pclass            3
# Sex            male
# Age              80
# SibSp             8
# Parch             6
# Fare        512.329
# Cabin             T
# Embarked          S
# dtype: object

# %%
df.mode()
# Out:
#    Survived  Pclass   Sex   Age  SibSp  Parch  Fare        Cabin Embarked
# 0       0.0     3.0  male  24.0    0.0    0.0  8.05      B96 B98        S
# 1       NaN     NaN   NaN   NaN    NaN    NaN   NaN  C23 C25 C27      NaN
# 2       NaN     NaN   NaN   NaN    NaN    NaN   NaN           G6      NaN

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
