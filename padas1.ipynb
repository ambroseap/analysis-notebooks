# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
from numpy.random import randn
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pub_df = pd.read_csv('trade.csv')

# %%
pub_df.head(2)
# Out:
#   Direction  Year        Date   Weekday Current_Match Country Commodity  \
# 0   Exports  2015  31/01/2015  Saturday    01/02/2020     All       All
# 1   Exports  2015  01/02/2015    Sunday    02/02/2020     All       All
#
#   Transport_Mode Measure      Value  Cumulative
# 0            All       $  257000000   257000000
# 1            All       $  123000000   380000000

# %%
pub_df.tail(2)
# Out:
#        Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 29781  Reimports  2020  09/06/2020    Tuesday    09/06/2020     All       All
# 29782  Reimports  2020  10/06/2020  Wednesday    10/06/2020     All       All
#
#       Transport_Mode Measure    Value  Cumulative
# 29781            All       $        0    62000000
# 29782            All       $  1000000    64000000

# %%
pub_df.shape
# Out:
# (29783, 11)

# %%
pub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29783 entries, 0 to 29782
# Data columns (total 11 columns):
# Direction         29783 non-null object
# Year              29783 non-null int64
# Date              29783 non-null object
# Weekday           29783 non-null object
# Current_Match     29783 non-null object
# Country           29783 non-null object
# Commodity         29783 non-null object
# Transport_Mode    29783 non-null object
# Measure           29783 non-null object
# Value             29783 non-null int64
# Cumulative        29783 non-null int64
# dtypes: int64(3), object(8)
# memory usage: 2.5+ MB

# %%
pub_df.Date[2:7]
# Out:
# 2    02/02/2015
# 3    03/02/2015
# 4    04/02/2015
# 5    05/02/2015
# 6    06/02/2015
# Name: Date, dtype: object

# %%
pub_df[['Date', 'Country', 'Value']]
# Out:
#              Date Country      Value
# 0      31/01/2015     All  257000000
# 1      01/02/2015     All  123000000
# 2      02/02/2015     All  176000000
# 3      03/02/2015     All  115000000
# 4      04/02/2015     All   74000000
# 5      05/02/2015     All  119000000
# 6      06/02/2015     All  127000000
# 7      07/02/2015     All  206000000
# 8      08/02/2015     All  114000000
# 9      09/02/2015     All  202000000
# 10     10/02/2015     All   88000000
# 11     11/02/2015     All   67000000
# 12     12/02/2015     All  132000000
# 13     13/02/2015     All  143000000
# 14     14/02/2015     All  146000000
# 15     15/02/2015     All  111000000
# 16     16/02/2015     All  226000000
# 17     17/02/2015     All  171000000
# 18     18/02/2015     All  120000000
# 19     19/02/2015     All  157000000
# 20     20/02/2015     All  157000000
# 21     21/02/2015     All  184000000
# 22     22/02/2015     All  135000000
# 23     23/02/2015     All  185000000
# ...

# %%
pub_df.columns
# Out:
# Index([u'Direction', u'Year', u'Date', u'Weekday', u'Current_Match',
#        u'Country', u'Commodity', u'Transport_Mode', u'Measure', u'Value',
#        u'Cumulative'],
#       dtype='object')

# %%
pub_df.iloc[4]
# Out:
# Direction            Exports
# Year                    2015
# Date              04/02/2015
# Weekday            Wednesday
# Current_Match     05/02/2020
# Country                  All
# Commodity                All
# Transport_Mode           All
# Measure                    $
# Value               74000000
# Cumulative         746000000
# Name: 4, dtype: object

# %%
pub_df.iloc[[4]]
# Out:
#   Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 4   Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
#
#   Transport_Mode Measure     Value  Cumulative
# 4            All       $  74000000   746000000

# %%
pub_df.iloc[[5],7]
# Out:
# 5    All
# Name: Transport_Mode, dtype: object

# %%
pub_df.loc[[1,2,5,8,9],['Date', 'Value']]
# Out:
#          Date      Value
# 1  01/02/2015  123000000
# 2  02/02/2015  176000000
# 5  05/02/2015  119000000
# 8  08/02/2015  114000000
# 9  09/02/2015  202000000

# %%
pub_df.loc[2:6, 'Date']
# Out:
# 2    02/02/2015
# 3    03/02/2015
# 4    04/02/2015
# 5    05/02/2015
# 6    06/02/2015
# Name: Date, dtype: object

# %%
pub_df.loc[2:6,['Date', 'Value']]
# Out:
#          Date      Value
# 2  02/02/2015  176000000
# 3  03/02/2015  115000000
# 4  04/02/2015   74000000
# 5  05/02/2015  119000000
# 6  06/02/2015  127000000

# %%
pub_df.loc[2:7, 'Date': 'Value']
# Out:
#          Date    Weekday Current_Match Country Commodity Transport_Mode  \
# 2  02/02/2015     Monday    03/02/2020     All       All            All
# 3  03/02/2015    Tuesday    04/02/2020     All       All            All
# 4  04/02/2015  Wednesday    05/02/2020     All       All            All
# 5  05/02/2015   Thursday    06/02/2020     All       All            All
# 6  06/02/2015     Friday    07/02/2020     All       All            All
# 7  07/02/2015   Saturday    08/02/2020     All       All            All
#
#   Measure      Value
# 2       $  176000000
# 3       $  115000000
# 4       $   74000000
# 5       $  119000000
# 6       $  127000000
# 7       $  206000000

# %%
pub_df['Value'].value_counts()
# Out:
# 0            1722
# 1000000      1259
# 1000         1235
# 2000000      1088
# 3000000       831
# 4000000       795
# 2000          754
# 5000000       723
# 6000000       679
# 9000000       558
# 8000000       553
# 7000000       552
# 12000000      546
# 3000          540
# 10000000      528
# 14000000      517
# 11000000      489
# 13000000      471
# 15000000      469
# 16000000      395
# 17000000      377
# 18000000      369
# 20000000      368
# 4000          342
# 21000000      337
# 22000000      315
# 19000000      311
# 23000000      309
# 24000000      281
# 25000000      275
#              ...
# 205000          1
# 156000          1
# 141000          1
# 170000          1
# 265000000       1
# 352000000       1
# 357000000       1
# 323000000       1
# 202000          1
# 298000000       1
# 168000          1
# 297000000       1
# 186000          1
# 336000000       1
# 291000000       1
# 261000000       1
# 135000          1
# 381000000       1
# 290000000       1
# ...

# %%
pub_df.set_index('Country')
# Out:
#          Direction  Year        Date    Weekday Current_Match Commodity  \
# Country
# All        Exports  2015  31/01/2015   Saturday    01/02/2020       All
# All        Exports  2015  01/02/2015     Sunday    02/02/2020       All
# All        Exports  2015  02/02/2015     Monday    03/02/2020       All
# All        Exports  2015  03/02/2015    Tuesday    04/02/2020       All
# All        Exports  2015  04/02/2015  Wednesday    05/02/2020       All
# All        Exports  2015  05/02/2015   Thursday    06/02/2020       All
# All        Exports  2015  06/02/2015     Friday    07/02/2020       All
# All        Exports  2015  07/02/2015   Saturday    08/02/2020       All
# All        Exports  2015  08/02/2015     Sunday    09/02/2020       All
# All        Exports  2015  09/02/2015     Monday    10/02/2020       All
# All        Exports  2015  10/02/2015    Tuesday    11/02/2020       All
# All        Exports  2015  11/02/2015  Wednesday    12/02/2020       All
# ...

# %%
pub_df.sort_index
# Out:
# <bound method DataFrame.sort_index of        Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6        Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7        Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8        Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9        Exports  2015  09/02/2015     Monday    10/02/2020     All       All
# ...

# %%
pub_df['Weekday'] =='Friday'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13        True
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27        True
# 28       False
# 29       False
#          ...
# 29753    False
# 29754    False
# 29755    False
# 29756     True
# 29757    False
# 29758    False
# 29759    False
# 29760    False
# 29761    False
# 29762    False
# 29763     True
# 29764    False
# 29765    False
# 29766    False
# 29767    False
# 29768    False
# 29769    False
# 29770     True
# 29771    False
# 29772    False
# 29773    False
# 29774    False
# 29775    False
# 29776    False
# 29777     True
# 29778    False
# 29779    False
# ...

# %%
filt= pub_df['Weekday'] == 'Friday'

# %%
pub_df[filt]
# Out:
#        Direction  Year        Date Weekday Current_Match Country Commodity  \
# 6        Exports  2015  06/02/2015  Friday    07/02/2020     All       All
# 13       Exports  2015  13/02/2015  Friday    14/02/2020     All       All
# 20       Exports  2015  20/02/2015  Friday    21/02/2020     All       All
# 27       Exports  2015  27/02/2015  Friday    28/02/2020     All       All
# 34       Exports  2015  06/03/2015  Friday    06/03/2020     All       All
# 41       Exports  2015  13/03/2015  Friday    13/03/2020     All       All
# 48       Exports  2015  20/03/2015  Friday    20/03/2020     All       All
# 55       Exports  2015  27/03/2015  Friday    27/03/2020     All       All
# 62       Exports  2015  03/04/2015  Friday    03/04/2020     All       All
# 69       Exports  2015  10/04/2015  Friday    10/04/2020     All       All
# 76       Exports  2015  17/04/2015  Friday    17/04/2020     All       All
# ...

# %%
filt= pub_df['Weekday'] == 'Monday'
pub_df[filt]
# Out:
#        Direction  Year        Date Weekday Current_Match Country Commodity  \
# 2        Exports  2015  02/02/2015  Monday    03/02/2020     All       All
# 9        Exports  2015  09/02/2015  Monday    10/02/2020     All       All
# 16       Exports  2015  16/02/2015  Monday    17/02/2020     All       All
# 23       Exports  2015  23/02/2015  Monday    24/02/2020     All       All
# 30       Exports  2015  02/03/2015  Monday    02/03/2020     All       All
# 37       Exports  2015  09/03/2015  Monday    09/03/2020     All       All
# 44       Exports  2015  16/03/2015  Monday    16/03/2020     All       All
# 51       Exports  2015  23/03/2015  Monday    23/03/2020     All       All
# 58       Exports  2015  30/03/2015  Monday    30/03/2020     All       All
# 65       Exports  2015  06/04/2015  Monday    06/04/2020     All       All
# 72       Exports  2015  13/04/2015  Monday    13/04/2020     All       All
# ...

# %%
high_value =(pub_df['Value']> 79000000)

# %%
pub_df.loc[high_value]
# Out:
#       Direction  Year        Date    Weekday Current_Match Country  \
# 0       Exports  2015  31/01/2015   Saturday    01/02/2020     All
# 1       Exports  2015  01/02/2015     Sunday    02/02/2020     All
# 2       Exports  2015  02/02/2015     Monday    03/02/2020     All
# 3       Exports  2015  03/02/2015    Tuesday    04/02/2020     All
# 5       Exports  2015  05/02/2015   Thursday    06/02/2020     All
# 6       Exports  2015  06/02/2015     Friday    07/02/2020     All
# 7       Exports  2015  07/02/2015   Saturday    08/02/2020     All
# 8       Exports  2015  08/02/2015     Sunday    09/02/2020     All
# 9       Exports  2015  09/02/2015     Monday    10/02/2020     All
# 10      Exports  2015  10/02/2015    Tuesday    11/02/2020     All
# 12      Exports  2015  12/02/2015   Thursday    13/02/2020     All
# 13      Exports  2015  13/02/2015     Friday    14/02/2020     All
# 14      Exports  2015  14/02/2015   Saturday    15/02/2020     All
# ...

# %%
high_value =(pub_df['Value']> 79000000)
pub_df.loc[high_value,['Date', 'Weekday', 'Value']]
# Out:
#              Date    Weekday      Value
# 0      31/01/2015   Saturday  257000000
# 1      01/02/2015     Sunday  123000000
# 2      02/02/2015     Monday  176000000
# 3      03/02/2015    Tuesday  115000000
# 5      05/02/2015   Thursday  119000000
# 6      06/02/2015     Friday  127000000
# 7      07/02/2015   Saturday  206000000
# 8      08/02/2015     Sunday  114000000
# 9      09/02/2015     Monday  202000000
# 10     10/02/2015    Tuesday   88000000
# 12     12/02/2015   Thursday  132000000
# 13     13/02/2015     Friday  143000000
# 14     14/02/2015   Saturday  146000000
# 15     15/02/2015     Sunday  111000000
# 16     16/02/2015     Monday  226000000
# 17     17/02/2015    Tuesday  171000000
# 18     18/02/2015  Wednesday  120000000
# 19     19/02/2015   Thursday  157000000
# 20     20/02/2015     Friday  157000000
# 21     21/02/2015   Saturday  184000000
# 22     22/02/2015     Sunday  135000000
# 23     23/02/2015     Monday  185000000
# ...

# %%
pub_df.columns = [d.lower() for d in pub_df.columns]

# %%
pub_df
# Out:
#        direction  year        date    weekday current_match country commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6        Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7        Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8        Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9        Exports  2015  09/02/2015     Monday    10/02/2020     All       All
# 10       Exports  2015  10/02/2015    Tuesday    11/02/2020     All       All
# ...

# %%
pub_df.apply(pd.Series.max)
# Out:
# direction             Reimports
# year                       2020
# date                 31/05/2020
# weekday               Wednesday
# current_match        31/05/2020
# country           United States
# commodity               Seafood
# transport_mode              Sea
# measure                  Tonnes
# value                 396000000
# cumulative          23334000000
# dtype: object

# %%
pub_df.drop(columns=['date'])
# Out:
#        direction  year    weekday current_match country commodity  \
# 0        Exports  2015   Saturday    01/02/2020     All       All
# 1        Exports  2015     Sunday    02/02/2020     All       All
# 2        Exports  2015     Monday    03/02/2020     All       All
# 3        Exports  2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015   Thursday    06/02/2020     All       All
# 6        Exports  2015     Friday    07/02/2020     All       All
# 7        Exports  2015   Saturday    08/02/2020     All       All
# 8        Exports  2015     Sunday    09/02/2020     All       All
# 9        Exports  2015     Monday    10/02/2020     All       All
# 10       Exports  2015    Tuesday    11/02/2020     All       All
# 11       Exports  2015  Wednesday    12/02/2020     All       All
# 12       Exports  2015   Thursday    13/02/2020     All       All
# ...

# %%
pub_df.sort_values(by='country')
# Out:
#       direction  year        date    weekday current_match        country  \
# 0       Exports  2015  31/01/2015   Saturday    01/02/2020            All
# 19306   Exports  2019  05/02/2019    Tuesday    04/02/2020            All
# 19305   Exports  2019  04/02/2019     Monday    03/02/2020            All
# 19304   Exports  2019  03/02/2019     Sunday    02/02/2020            All
# 19303   Exports  2019  02/02/2019   Saturday    01/02/2020            All
# 19302   Exports  2018  13/06/2018  Wednesday    10/06/2020            All
# 19301   Exports  2018  12/06/2018    Tuesday    09/06/2020            All
# 19300   Exports  2018  11/06/2018     Monday    08/06/2020            All
# 19299   Exports  2018  10/06/2018     Sunday    07/06/2020            All
# 19298   Exports  2018  09/06/2018   Saturday    06/06/2020            All
# 19297   Exports  2018  08/06/2018     Friday    05/06/2020            All
# 19296   Exports  2018  07/06/2018   Thursday    04/06/2020            All
# ...

# %%
pub_df['value'].nlargest(10)
# Out:
# 23301    396000000
# 29       386000000
# 23342    386000000
# 23418    381000000
# 541      373000000
# 7103     373000000
# 152      367000000
# 7615     357000000
# 23347    354000000
# 7226     353000000
# Name: value, dtype: int64

# %%
pub_df.iloc[152]
# Out:
# direction            Exports
# year                    2016
# date              20/02/2016
# weekday             Saturday
# current_match     22/02/2020
# country                  All
# commodity                All
# transport_mode           All
# measure                    $
# value              367000000
# cumulative        3359000000
# Name: 152, dtype: object

# %%
pub_df.mean
# Out:
# <bound method DataFrame.mean of        direction  year        date    weekday current_match country commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6        Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7        Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8        Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9        Exports  2015  09/02/2015     Monday    10/02/2020     All       All
# 10       Exports  2015  10/02/2015    Tuesday    11/02/2020     All       All
# ...

# %%
pub_df.describe()
# Out:
#                year         value    cumulative
# count  29783.000000  2.978300e+04  2.978300e+04
# mean    2017.497599  3.257695e+07  2.127959e+09
# std        1.707210  5.362694e+07  3.704585e+09
# min     2015.000000  0.000000e+00  0.000000e+00
# 25%     2016.000000  1.000000e+06  4.100000e+07
# 50%     2017.000000  1.100000e+07  6.610000e+08
# 75%     2019.000000  3.400000e+07  2.190000e+09
# max     2020.000000  3.960000e+08  2.333400e+10

# %%
pub_df['value'].value_counts()
# Out:
# 0            1722
# 1000000      1259
# 1000         1235
# 2000000      1088
# 3000000       831
# 4000000       795
# 2000          754
# 5000000       723
# 6000000       679
# 9000000       558
# 8000000       553
# 7000000       552
# 12000000      546
# 3000          540
# 10000000      528
# 14000000      517
# 11000000      489
# 13000000      471
# 15000000      469
# 16000000      395
# 17000000      377
# 18000000      369
# 20000000      368
# 4000          342
# 21000000      337
# 22000000      315
# 19000000      311
# 23000000      309
# 24000000      281
# 25000000      275
#              ...
# 205000          1
# 156000          1
# 141000          1
# 170000          1
# 265000000       1
# 352000000       1
# 357000000       1
# 323000000       1
# 202000          1
# 298000000       1
# 168000          1
# 297000000       1
# 186000          1
# 336000000       1
# 291000000       1
# 261000000       1
# 135000          1
# 381000000       1
# 290000000       1
# ...

# %%
pub_df['value'].value_counts(normalize= True)
# Out:
# 0            0.057818
# 1000000      0.042272
# 1000         0.041467
# 2000000      0.036531
# 3000000      0.027902
# 4000000      0.026693
# 2000         0.025316
# 5000000      0.024276
# 6000000      0.022798
# 9000000      0.018736
# 8000000      0.018568
# 7000000      0.018534
# 12000000     0.018333
# 3000         0.018131
# 10000000     0.017728
# 14000000     0.017359
# 11000000     0.016419
# 13000000     0.015814
# 15000000     0.015747
# 16000000     0.013263
# 17000000     0.012658
# 18000000     0.012390
# 20000000     0.012356
# 4000         0.011483
# 21000000     0.011315
# 22000000     0.010577
# 19000000     0.010442
# 23000000     0.010375
# 24000000     0.009435
# 25000000     0.009233
#                ...
# 205000       0.000034
# 156000       0.000034
# 141000       0.000034
# 170000       0.000034
# 265000000    0.000034
# 352000000    0.000034
# 357000000    0.000034
# 323000000    0.000034
# 202000       0.000034
# 298000000    0.000034
# ...

# %%
pub_df
# Out:
#        direction  year        date    weekday current_match country commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6        Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7        Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8        Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9        Exports  2015  09/02/2015     Monday    10/02/2020     All       All
# 10       Exports  2015  10/02/2015    Tuesday    11/02/2020     All       All
# ...

# %%
gender_grp = pub_df.groupby(['weekday'])

# %%
gender_grp.get_group('Friday')
# Out:
#        direction  year        date weekday current_match country commodity  \
# 6        Exports  2015  06/02/2015  Friday    07/02/2020     All       All
# 13       Exports  2015  13/02/2015  Friday    14/02/2020     All       All
# 20       Exports  2015  20/02/2015  Friday    21/02/2020     All       All
# 27       Exports  2015  27/02/2015  Friday    28/02/2020     All       All
# 34       Exports  2015  06/03/2015  Friday    06/03/2020     All       All
# 41       Exports  2015  13/03/2015  Friday    13/03/2020     All       All
# 48       Exports  2015  20/03/2015  Friday    20/03/2020     All       All
# 55       Exports  2015  27/03/2015  Friday    27/03/2020     All       All
# 62       Exports  2015  03/04/2015  Friday    03/04/2020     All       All
# 69       Exports  2015  10/04/2015  Friday    10/04/2020     All       All
# 76       Exports  2015  17/04/2015  Friday    17/04/2020     All       All
# ...

# %%
pub_df.isna
# Out:
# <bound method DataFrame.isna of        direction  year        date    weekday current_match country commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6        Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7        Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8        Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9        Exports  2015  09/02/2015     Monday    10/02/2020     All       All
# 10       Exports  2015  10/02/2015    Tuesday    11/02/2020     All       All
# ...

# %%
pub_df.fillna('missingmissing')
# Out:
#        direction  year        date    weekday current_match country commodity  \
# 0        Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1        Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2        Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3        Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4        Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# 5        Exports  2015  05/02/2015   Thursday    06/02/2020     All       All
# 6        Exports  2015  06/02/2015     Friday    07/02/2020     All       All
# 7        Exports  2015  07/02/2015   Saturday    08/02/2020     All       All
# 8        Exports  2015  08/02/2015     Sunday    09/02/2020     All       All
# 9        Exports  2015  09/02/2015     Monday    10/02/2020     All       All
# 10       Exports  2015  10/02/2015    Tuesday    11/02/2020     All       All
# ...

# %%
gender_grp.get_group('Friday')
# Out:
#        direction  year        date weekday current_match country commodity  \
# 6        Exports  2015  06/02/2015  Friday    07/02/2020     All       All
# 13       Exports  2015  13/02/2015  Friday    14/02/2020     All       All
# 20       Exports  2015  20/02/2015  Friday    21/02/2020     All       All
# 27       Exports  2015  27/02/2015  Friday    28/02/2020     All       All
# 34       Exports  2015  06/03/2015  Friday    06/03/2020     All       All
# 41       Exports  2015  13/03/2015  Friday    13/03/2020     All       All
# 48       Exports  2015  20/03/2015  Friday    20/03/2020     All       All
# 55       Exports  2015  27/03/2015  Friday    27/03/2020     All       All
# 62       Exports  2015  03/04/2015  Friday    03/04/2020     All       All
# 69       Exports  2015  10/04/2015  Friday    10/04/2020     All       All
# 76       Exports  2015  17/04/2015  Friday    17/04/2020     All       All
# ...

# %%
filt = (pub_df['weekday']== 'Friday')

Man_df = pub_df.loc[filt]


Man_df.head()
# Out:
#    direction  year        date weekday current_match country commodity  \
# 6    Exports  2015  06/02/2015  Friday    07/02/2020     All       All
# 13   Exports  2015  13/02/2015  Friday    14/02/2020     All       All
# 20   Exports  2015  20/02/2015  Friday    21/02/2020     All       All
# 27   Exports  2015  27/02/2015  Friday    28/02/2020     All       All
# 34   Exports  2015  06/03/2015  Friday    06/03/2020     All       All
#
#    transport_mode measure      value  cumulative
# 6             All       $  127000000   992000000
# 13            All       $  143000000  1944000000
# 20            All       $  157000000  3032000000
# 27            All       $  127000000  4000000000
# 34            All       $  153000000  5350000000

# %%
Man_df.to_csv('public.csv')

# %%
Man_df.to_csv('public.tsv', sep='\t')

# %%
df = pd.read_csv('public.tsv', sep='\t')

# %%
df
# Out:
#       Unnamed: 0  direction  year        date weekday current_match country  \
# 0              6    Exports  2015  06/02/2015  Friday    07/02/2020     All
# 1             13    Exports  2015  13/02/2015  Friday    14/02/2020     All
# 2             20    Exports  2015  20/02/2015  Friday    21/02/2020     All
# 3             27    Exports  2015  27/02/2015  Friday    28/02/2020     All
# 4             34    Exports  2015  06/03/2015  Friday    06/03/2020     All
# 5             41    Exports  2015  13/03/2015  Friday    13/03/2020     All
# 6             48    Exports  2015  20/03/2015  Friday    20/03/2020     All
# 7             55    Exports  2015  27/03/2015  Friday    27/03/2020     All
# 8             62    Exports  2015  03/04/2015  Friday    03/04/2020     All
# 9             69    Exports  2015  10/04/2015  Friday    10/04/2020     All
# 10            76    Exports  2015  17/04/2015  Friday    17/04/2020     All
# ...
