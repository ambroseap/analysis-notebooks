# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=tips)

# %% [markdown]
# now lets know who are the smokers when compare to the total bill and tips to kniw the population of those who say yes or no that they are smoker

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=tips, hue='smoker')

# %% [markdown]
# i think there more no smokers than the yes smpoker

# %%
#to be very sure if the no are more thatn the yse people

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
c

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=tips, hue='size', color='red')

# %%
#size inctease 

sns.relplot(x = 'total_bill', y = 'tip', data=tips, size='size', sizes= (15,200) )

# %%
sns.relplot(x = 'total_bill', y = 'tip', data=tips, size='size', sizes= (100,200))

# %%
sns.relplot(x = 'total_bill', y = 'tip', kind='line', data=tips, )

# %%
sns.barplot(x = 'total_bill', y = 'tip', data=tips)

# %%
sns.boxplot(x = 'total_bill', y = 'tip', data=tips)

# %%
sns.barplot(x = 'total_bill', y = 'tip', hue='size', data=tips)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', data=tips)

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', hue='size', data=tips)

# %% [markdown]
# now lets load another dataset

# %%
fmri =sns.load_dataset('fmri')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind='line', data=fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind='line', data=fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind='line', data=fmri, ci = False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator=None, kind='line', data=fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator=None, hue ='event', kind='line', data=fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue ='event', kind='line', data=fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue ='region', style='event',kind='line', data=fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue ='region', style='event',kind='line', data=fmri, marker=True)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue ='region', style='event',kind='line', data=fmri, marker=True, dashes=False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue ='region', style='event',kind='line', estimator=None, data=fmri, marker=True, dashes=False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue ='region', style='event',kind='line', estimator=None, data=fmri.query()"even== 'stim'", marker=True, dashes=False)
# Out:
#   File "<ipython-input-56-57d4d4d3e9fb>", line 1
#     sns.relplot(x = 'timepoint', y = 'signal', hue ='region', style='event',kind='line', estimator=None, data=fmri.query()"even== 'stim'", marker=True, dashes=False)
#                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
#another dATASET

# %%
dots = sns.load_dataset('dots').query("align =='dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x = 'time', y = 'firing_rate', kind='line', data=dots)

# %%
sns.relplot(x = 'time', y = 'firing_rate', kind='line', data=dots, hue='coherence',)

# %%
sns.relplot(x = 'time', y = 'firing_rate', kind='line', data=dots, hue='coherence', style='choice')

# %%
#another dataframe

# %%
dd = pd.DataFrame(dict(time=pd.date_range('2019-06-02',periods=1000), value=randn(1000).cumsum()))

# %%
dd.head()
# Out:
#         time     value
# 0 2019-06-02  2.062113
# 1 2019-06-03  0.681636
# 2 2019-06-04  0.548715
# 3 2019-06-05  0.510430
# 4 2019-06-06  0.776479

# %%
sns.relplot(x = 'time', y = 'value', kind='line', data=dd)

# %%
g= sns.relplot(x = 'time', y = 'value', kind='line', data=dd)
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker',col='time', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker', kind='line', col='time', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker', col='size', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker', kind='line', col='size', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker', col='sex', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker', kind='line', col='sex', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker',row='time', data=tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue='smoker', kind='line', row='size', data=tips)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue='subject',col='region', row='event', height=4, kind= 'line', estimator=None, data=fmri)

# %%
sns.relplot(x = 'time', y = 'firing_rate', kind='line', height=9, data=dots)

# %%
sns.relplot(x = 'time', y = 'firing_rate', kind='line', data=dots, height=9, hue='coherence',)

# %%
sns.lineplot(x = 'timepoint', y = 'signal', style='event',hue='region', marker=True, ci=100, err_style='bars', data=fmri)

# %%
#lineplot


sns.lineplot(x = 'timepoint', y = 'signal', style='event', marker=True, ci=80, err_style='bars', data=fmri)

# %%
sns.catplot(x = 'day', y = 'total_bill',  data=tips)

# %%
sns.catplot(x = 'day', y = 'total_bill',  data=tips, kind='swarm',)

# %%
#swam plot

sns.catplot(x = 'day', y = 'total_bill',  data=tips, kind='swarm', hue='sex')

# %%
sns.swarmplot(x = 'day', y = 'total_bill',  data=tips, hue='sex')

# %%
sns.catplot(x = 'day', y = 'total_bill',  data=tips,)

# %%
#box plot



sns.catplot(x = 'day', y = 'total_bill',  data=tips, kind='box')

# %%
sns.boxplot(x = 'day', y = 'total_bill',  data=tips,)

# %%
sns.boxplot(x = 'day', y = 'total_bill',  data=tips, hue='time')

# %%
sns.boxplot(x = 'day', y = 'total_bill',  data=tips, hue='time', dodge=False)

# %%
sns.boxplot(x = 'day', y = 'total_bill',  data=tips, hue='sex', dodge=False)

# %%
#boxenplot



sns.catplot(x = 'day', y = 'total_bill', kind='boxen', data=tips.sort_values('day'))

# %% [markdown]
# # lets create another dataset for better use of the boxenplot

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind='boxen', data=diamonds.sort_values('color'))

# %%
sns.catplot(x = 'color', y = 'price', kind='boxen', data=diamonds.sort_values('color'))

# %%
sns.boxenplot(x = 'color', y = 'price', data=diamonds.sort_values('color'))

# %%
#violinplot

# %%
sns.catplot(x = 'color', y = 'price', kind='violin',data=diamonds)

# %% [markdown]
# # lets create another dataset for better use of the violinplot

# %%
sns.catplot(x = 'total_bill', y = 'day', hue='time', kind='violin', data=tips)

# %%
sns.violinplot(x = 'total_bill', y = 'day', hue='time', data=tips)

# %%
sns.violinplot(x = 'total_bill', y = 'day', hue='sex', data=tips)

# %%
sns.violinplot(x = 'total_bill', y = 'day', hue='sex', data=tips, split=True)

# %%
sns.violinplot(x = 'total_bill', y = 'day', hue='sex', data=tips, split=True, inner='stick')

# %% [markdown]
# # combine or jiont plot.    violin and swarmplot

# %%
g= sns.catplot(x = 'day', y = 'total_bill', kind='violin', inner=None, data=tips,)
sns.swarmplot(x = 'day', y = 'total_bill', color='black', size=5, data=tips, )

# %%
sns.barplot(x = 'day', y = 'total_bill', hue='sex', data=tips)

# %% [markdown]
# # lets create another dataset

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head(8)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# ...

# %%
#barplot


sns.catplot(x = 'sex', y = 'survived', hue='class', kind='bar', data=titanic,)

# %%
sns.catplot(x = 'deck',  kind = 'count',  data=titanic,)

# %%
sns.catplot(x = 'deck',  kind = 'count',  hue='class', data=titanic,)

# %%
#pointplot


sns.catplot(x = 'sex', y = 'survived', hue='class', kind='point', data=titanic,)

# %%
sns.pointplot(x = 'sex', y = 'survived', hue='class', data=titanic,)

# %% [markdown]
# # visualizing distribution of data

# %%
x =randn(100)
sns.distplot(x)

# %%
x =randn(100)
sns.distplot(x, kde=False)

# %%
x =randn(100)
sns.distplot(x, kde=False, rug=True)

# %%
x =randn(100)
sns.distplot(x, rug=True)

# %%
x =randn(100)
sns.distplot(x, rug=True, bins=50)

# %%
x =randn(100)
sns.distplot(x, rug=True, hist=False)

# %%
sns.kdeplot(x, shade=True,)

# %%
sns.kdeplot(x, shade=True, cbar=True)

# %%
sns.kdeplot(x, shade=True, cbar=True, bw=3)

# %%
sns.kdeplot(x, shade=True, cbar=True, bw=5, cut=1)

# %% [markdown]
# # now let plot the x axis and the y axis

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # now let create a joint plot

# %%
x = tips['total_bill']
y = tips['tip']

# %%
f, ax = plt.subplots(figsize =(6,6))
cmap = sns.cubehelix_palette(as_cmap =True, dark=0, light=1, reverse=True)
sns.kdeplot(x,y,cmap=cmap, n_levels=60, shade=True)

# %%
j = sns.jointplot(x =x, y=y, kind='kde')

# %%
g = sns.jointplot(x, y, kind='kde', color='b')

# %%
g = sns.jointplot(x,y, kind='kde', color='k')
g.plot_joint(plt.scatter, c='w', s=50, linewidth=1, marker='+')
g.ax_joint.collections[0]

# %% [markdown]
# # pairplot

# %%
sns.pairplot(iris)

# %%
g= sns.PairGrid(iris)

g.map_diag(sns.kdeplot)

# %%
g= sns.PairGrid(iris)

g.map_diag(sns.kdeplot)

g.map_offdiag(sns.kdeplot,)

# %% [markdown]
# # now lets do something in linear regression and relationship

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x = 'total_bill', y = 'tip', data=tips)

# %%
sns.regplot(x = 'size', y = 'total_bill',  data=tips, )

# %%
sns.regplot(x = 'size', y = 'total_bill',  data=tips, x_estimator=np.mean )

# %%
sns.lmplot(x = 'total_bill', y = 'size', hue='sex',  data=tips )

# %%
sns.lmplot(x = 'total_bill', y = 'size', hue='sex',  data=tips, markers=['o','x'] , col='time')

# %%
sns.lmplot(x = 'total_bill', y = 'size', hue='sex',  data=tips, markers=['o','x'] , col='time', row='smoker')

# %%
f, ax= plt.subplots(figsize=(5,6))
sns.regplot(x = 'total_bill', y = 'tip', data=tips, ax=ax)

# %%
f, ax= plt.subplots(figsize=(10,11))
sns.regplot(x = 'total_bill', y = 'tip', data=tips, ax=ax)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data=tips, col='day')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data=tips,col='day', col_wrap=2)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data=tips,col='day', col_wrap=2, height=6)

# %% [markdown]
# # controlling ploted figure aesthetic

# %% [markdown]
# # sinplot

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sinplot(-1)

# %%
sns.set_style('whitegrid')

# %%
sinplot()

# %%
sns.set_style('darkgrid')

# %%
sinplot()

# %%
sns.set_style('white')

# %%
sinplot()

# %%
sns.set_style('ticks')
sns.despine(left=True)
sinplot()

# %%
sinplot()

# %% [markdown]
# # catplot
# scatterplot
# lineplot
# relplot
# swarmplot
# boxplot
# boxenplot
# violinplot
# barplot
# poitplot
# pairplot
#
#
# for distribution of data, we use
# rug plot
# kde plot
# dist plot
# pairplot
# regplot............................that regression plot
# sinplot
